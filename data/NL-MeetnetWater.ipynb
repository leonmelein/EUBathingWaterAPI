# %%
url = ""

# %%
import requests
import json

# %%
req = requests.get(url)
data = req.json()

# %%
data
# Out:
# {'t0': '2023-02-12T18:10:00Z',
#  'series': [{'name': 'Watertemperatuur in oC',
#    'unit': '°C',
#    'color': '#0178ca',
#    'isWindDirection': False,
#    'data': [{'dateTime': '2023-02-10T18:30:00Z',
#      'value': 4.4,
#      'sign': None,
#      'entryCreated': '0001-01-01T00:00:00'},
#     {'dateTime': '2023-02-10T18:40:00Z',
#      'value': 4.4,
#      'sign': None,
#      'entryCreated': '0001-01-01T00:00:00'},
#     {'dateTime': '2023-02-10T18:50:00Z',
#      'value': 4.4,
#      'sign': None,
#      'entryCreated': '0001-01-01T00:00:00'},
#     {'dateTime': '2023-02-10T19:00:00Z',
#      'value': 4.4,
#      'sign': None,
#      'entryCreated': '0001-01-01T00:00:00'},
#     {'dateTime': '2023-02-10T19:10:00Z',
#      'value': 4.4,
#      'sign': None,
#      'entryCreated': '0001-01-01T00:00:00'},
#     {'dateTime': '2023-02-10T19:20:00Z',
#      'value': 4.4,
#      'sign': None,
#      'entryCreated': '0001-01-01T00:00:00'},
#     {'dateTime': '2023-02-10T19:30:00Z',
# ...

# %%
data['series'][0]['data'][0]['value']
# Out:
# 4.4
