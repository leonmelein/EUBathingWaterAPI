# %%
import sqlite3
import requests
import pandas as pd

# %%
server = "https://api3.geo.admin.ch/rest/services/api/MapServer/find?layer=ch.bafu.gewaesserschutz-badewasserqualitaet&sr=4326&geometryFormat=geojson&searchText=CH&searchField=id"

# %%
response = requests.get(server)
response.json()
# Out:
# {'results': [{'type': 'Feature',
#    'featureId': 'CH10001',
#    'bbox': [7.087865, 46.675282, 7.087865, 46.675282],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH10001',
#    'geometry': {'type': 'Point', 'coordinates': [7.087865, 46.675282]},
#    'properties': {'bwname': 'Plage de Gumefens',
#     'groupid': None,
#     'nwunitname': 'Lac de la Gruyère',
#     'gemeinde': 'Pont-en-Ogoz',
#     'canton': 'FR',
#     'bwatercat': 'See',
#     'url': 'https://www.fr.ch/de/ilfd/news/die-mikrobiologische-wasserqualitaet-der-offiziellen-strandbaeder-ist-gut',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Plage de Gumefens'}},
#   {'type': 'Feature',
#    'featureId': 'CH10004',
#    'bbox': [7.110896, 46.927943, 7.110896, 46.927943],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH10004',
#    'geometry': {'type': 'Point', 'coordinates': [7.110896, 46.927943]},
#    'properties': {'bwname': 'Gemeinde Strandbad',
#     'groupid': None,
#     'nwunitname': 'Lac de Morat',
#     'gemeinde': 'Morat',
#     'canton': 'FR',
#     'bwatercat': 'See',
#     'url': 'https://www.fr.ch/de/ilfd/news/die-mikrobiologische-wasserqualitaet-der-offiziellen-strandbaeder-ist-gut',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Gemeinde Strandbad'}},
#   {'type': 'Feature',
#    'featureId': 'CH10007',
#    'bbox': [6.953375, 46.922705, 6.953375, 46.922705],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH10007',
#    'geometry': {'type': 'Point', 'coordinates': [6.953375, 46.922705]},
#    'properties': {'bwname': 'Plage de Portalban',
#     'groupid': None,
#     'nwunitname': 'Lac de Neuchâtel',
#     'gemeinde': 'Delley-Portalban',
#     'canton': 'FR',
#     'bwatercat': 'See',
#     'url': 'https://www.fr.ch/de/ilfd/news/die-mikrobiologische-wasserqualitaet-der-offiziellen-strandbaeder-ist-gut',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Plage de Portalban'}},
#   {'type': 'Feature',
#    'featureId': 'CH10009',
#    'bbox': [6.848274, 46.857082, 6.848274, 46.857082],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH10009',
#    'geometry': {'type': 'Point', 'coordinates': [6.848274, 46.857082]},
#    'properties': {'bwname': 'Nouvelle plage',
#     'groupid': None,
#     'nwunitname': 'Lac de Neuchâtel',
#     'gemeinde': 'Estavayer-le-Lac',
#     'canton': 'FR',
#     'bwatercat': 'See',
#     'url': 'https://www.fr.ch/de/ilfd/news/die-mikrobiologische-wasserqualitaet-der-offiziellen-strandbaeder-ist-gut',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Nouvelle plage'}},
#   {'type': 'Feature',
#    'featureId': 'CH1013',
#    'bbox': [8.674674, 47.345638, 8.674674, 47.345638],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH1013',
#    'geometry': {'type': 'Point', 'coordinates': [8.674674, 47.345638]},
#    'properties': {'bwname': 'Strandbad Maur',
#     'groupid': None,
#     'nwunitname': 'Greifensee',
#     'gemeinde': 'Maur',
#     'canton': 'ZH',
#     'bwatercat': 'See',
#     'url': 'https://www.zh.ch/de/gesundheitsdirektion/kantonales-labor.html',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Strandbad Maur'}},
#   {'type': 'Feature',
#    'featureId': 'CH1016',
#    'bbox': [8.691118, 47.341413, 8.691118, 47.341413],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH1016',
#    'geometry': {'type': 'Point', 'coordinates': [8.691118, 47.341413]},
#    'properties': {'bwname': 'Strandbad Uster',
#     'groupid': None,
#     'nwunitname': 'Greifensee',
#     'gemeinde': 'Uster',
#     'canton': 'ZH',
#     'bwatercat': 'See',
#     'url': 'https://www.zh.ch/de/gesundheitsdirektion/kantonales-labor.html',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Strandbad Uster'}},
#   {'type': 'Feature',
#    'featureId': 'CH1029',
#    'bbox': [8.785508, 47.358341, 8.785508, 47.358341],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH1029',
#    'geometry': {'type': 'Point', 'coordinates': [8.785508, 47.358341]},
#    'properties': {'bwname': 'Strandbad Baumen',
#     'groupid': None,
#     'nwunitname': 'Pfäffikersee',
#     'gemeinde': 'Pfäffikon',
#     'canton': 'ZH',
#     'bwatercat': 'See',
#     'url': 'https://www.zh.ch/de/gesundheitsdirektion/kantonales-labor.html',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Strandbad Baumen'}},
#   {'type': 'Feature',
#    'featureId': 'CH1050',
#    'bbox': [8.582573, 47.309257, 8.582573, 47.309257],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH1050',
#    'geometry': {'type': 'Point', 'coordinates': [8.582573, 47.309257]},
#    'properties': {'bwname': 'Strandbad Küsnacht',
#     'groupid': None,
#     'nwunitname': 'Zürichsee',
#     'gemeinde': 'Küsnacht',
#     'canton': 'ZH',
#     'bwatercat': 'See',
#     'url': 'https://www.zh.ch/de/gesundheitsdirektion/kantonales-labor.html',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Strandbad Küsnacht'}},
#   {'type': 'Feature',
#    'featureId': 'CH1058',
#    'bbox': [8.717117, 47.239027, 8.717117, 47.239027],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH1058',
#    'geometry': {'type': 'Point', 'coordinates': [8.717117, 47.239027]},
#    'properties': {'bwname': 'Seebad Lattenberg',
#     'groupid': None,
#     'nwunitname': 'Zürichsee',
#     'gemeinde': 'Stäfa',
#     'canton': 'ZH',
#     'bwatercat': 'See',
#     'url': 'https://www.zh.ch/de/gesundheitsdirektion/kantonales-labor.html',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Seebad Lattenberg'}},
#   {'type': 'Feature',
#    'featureId': 'CH1061',
#    'bbox': [8.574869, 47.289093, 8.574869, 47.289093],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH1061',
#    'geometry': {'type': 'Point', 'coordinates': [8.574869, 47.289093]},
#    'properties': {'bwname': 'Strandbad Bürger',
#     'groupid': None,
#     'nwunitname': 'Zürichsee',
#     'gemeinde': 'Thalwil',
#     'canton': 'ZH',
#     'bwatercat': 'See',
#     'url': 'https://www.zh.ch/de/gesundheitsdirektion/kantonales-labor.html',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Strandbad Bürger'}},
#   {'type': 'Feature',
#    'featureId': 'CH1065',
#    'bbox': [8.660984, 47.239187, 8.660984, 47.239187],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH1065',
#    'geometry': {'type': 'Point', 'coordinates': [8.660984, 47.239187]},
#    'properties': {'bwname': 'Strandbad Reitliau',
#     'groupid': None,
#     'nwunitname': 'Zürichsee',
#     'gemeinde': 'Wädenswil',
#     'canton': 'ZH',
#     'bwatercat': 'See',
#     'url': 'https://www.zh.ch/de/gesundheitsdirektion/kantonales-labor.html',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Strandbad Reitliau'}},
#   {'type': 'Feature',
#    'featureId': 'CH11005',
#    'bbox': [7.523971, 47.197397, 7.523971, 47.197397],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH11005',
#    'geometry': {'type': 'Point', 'coordinates': [7.523971, 47.197397]},
#    'properties': {'bwname': 'Solothurn',
#     'groupid': None,
#     'nwunitname': 'Aare Bielersee-Rhein',
#     'gemeinde': 'Solothurn',
#     'canton': 'SO',
#     'bwatercat': 'Fluss',
#     'url': 'http://www.so.ch/badegewaesser/',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Solothurn'}},
#   {'type': 'Feature',
#    'featureId': 'CH14013',
#    'bbox': [8.639183, 47.694474, 8.639183, 47.694474],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH14013',
#    'geometry': {'type': 'Point', 'coordinates': [8.639183, 47.694474]},
#    'properties': {'bwname': 'Schaffhausen Rheinbad Rhybadi',
#     'groupid': None,
#     'nwunitname': 'Hochrhein',
#     'gemeinde': 'Schaffhausen',
#     'canton': 'SH',
#     'bwatercat': 'Fluss',
#     'url': 'http://www.interkantlab.ch/index.php?id=188&L=4',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '0',
#     'label': 'Schaffhausen Rheinbad Rhybadi'}},
#   {'type': 'Feature',
#    'featureId': 'CH14015',
#    'bbox': [8.849985, 47.663528, 8.849985, 47.663528],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH14015',
#    'geometry': {'type': 'Point', 'coordinates': [8.849985, 47.663528]},
#    'properties': {'bwname': 'Stein am Rhein Strandbad Niderfeld',
#     'groupid': None,
#     'nwunitname': 'Hochrhein',
#     'gemeinde': 'Stein am Rhein',
#     'canton': 'SH',
#     'bwatercat': 'Fluss',
#     'url': 'http://www.interkantlab.ch/index.php?id=188&L=4',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '0',
#     'label': 'Stein am Rhein Strandbad Niderfeld'}},
#   {'type': 'Feature',
#    'featureId': 'CH17003',
#    'bbox': [9.511395, 47.479695, 9.511395, 47.479695],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH17003',
#    'geometry': {'type': 'Point', 'coordinates': [9.511395, 47.479695]},
#    'properties': {'bwname': 'Strandbad Rorschach, Bodensee',
#     'groupid': None,
#     'nwunitname': 'Bodensee',
#     'gemeinde': 'Rorschach',
#     'canton': 'SG',
#     'bwatercat': 'See',
#     'url': 'https://www.sg.ch/gesundheit-soziales/verbraucherschutz/wasser/badewasser.html',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Strandbad Rorschach, Bodensee'}},
#   {'type': 'Feature',
#    'featureId': 'CH17028',
#    'bbox': [8.842148, 47.215729, 8.842148, 47.215729],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH17028',
#    'geometry': {'type': 'Point', 'coordinates': [8.842148, 47.215729]},
#    'properties': {'bwname': 'Strandbad Stampf, Zürichsee',
#     'groupid': None,
#     'nwunitname': 'Zürichsee',
#     'gemeinde': 'Rapperswil-Jona',
#     'canton': 'SG',
#     'bwatercat': 'See',
#     'url': 'https://www.sg.ch/gesundheit-soziales/verbraucherschutz/wasser/badewasser.html',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Strandbad Stampf, Zürichsee'}},
#   {'type': 'Feature',
#    'featureId': 'CH17041',
#    'bbox': [9.119504, 47.139257, 9.119504, 47.139257],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH17041',
#    'geometry': {'type': 'Point', 'coordinates': [9.119504, 47.139257]},
#    'properties': {'bwname': 'Badestrand Lago Mio',
#     'groupid': None,
#     'nwunitname': 'Walensee',
#     'gemeinde': 'Amden',
#     'canton': 'SG',
#     'bwatercat': 'See',
#     'url': 'https://www.sg.ch/gesundheit-soziales/verbraucherschutz/wasser/badewasser.html',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Badestrand Lago Mio'}},
#   {'type': 'Feature',
#    'featureId': 'CH19004',
#    'bbox': [8.209102, 47.271644, 8.209102, 47.271644],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH19004',
#    'geometry': {'type': 'Point', 'coordinates': [8.209102, 47.271644]},
#    'properties': {'bwname': 'Vor Badi',
#     'groupid': 'CHHALLWILERSEE',
#     'nwunitname': 'Hallwiler See',
#     'gemeinde': 'Beinwil am See',
#     'canton': 'AG',
#     'bwatercat': 'See',
#     'url': 'https://www.ag.ch/de/dgs/verbraucherschutz/lebensmittelkontrolle/badewasser/qualitaet_1/Qualitaet.jsp',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '2',
#     'label': 'Vor Badi'}},
#   {'type': 'Feature',
#    'featureId': 'CH19006',
#    'bbox': [8.217197, 47.303909, 8.217197, 47.303909],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH19006',
#    'geometry': {'type': 'Point', 'coordinates': [8.217197, 47.303909]},
#    'properties': {'bwname': 'Badi Tennwil',
#     'groupid': 'CHHALLWILERSEE',
#     'nwunitname': 'Hallwiler See',
#     'gemeinde': 'Meisterschwanden',
#     'canton': 'AG',
#     'bwatercat': 'See',
#     'url': 'https://www.ag.ch/de/dgs/verbraucherschutz/lebensmittelkontrolle/badewasser/qualitaet_1/Qualitaet.jsp',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '2',
#     'label': 'Badi Tennwil'}},
#   {'type': 'Feature',
#    'featureId': 'CH19007',
#    'bbox': [8.224707, 47.284941, 8.224707, 47.284941],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH19007',
#    'geometry': {'type': 'Point', 'coordinates': [8.224707, 47.284941]},
#    'properties': {'bwname': 'Seerose',
#     'groupid': 'CHHALLWILERSEE',
#     'nwunitname': 'Hallwiler See',
#     'gemeinde': 'Meisterschwanden',
#     'canton': 'AG',
#     'bwatercat': 'See',
#     'url': 'https://www.ag.ch/de/dgs/verbraucherschutz/lebensmittelkontrolle/badewasser/qualitaet_1/Qualitaet.jsp',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '2',
#     'label': 'Seerose'}},
#   {'type': 'Feature',
#    'featureId': 'CH20004',
#    'bbox': [9.435648, 47.519417, 9.435648, 47.519417],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH20004',
#    'geometry': {'type': 'Point', 'coordinates': [9.435648, 47.519417]},
#    'properties': {'bwname': 'Schwimmbad Arbon',
#     'groupid': None,
#     'nwunitname': 'Bodensee',
#     'gemeinde': 'Arbon',
#     'canton': 'TG',
#     'bwatercat': 'See',
#     'url': 'https://kantlab.tg.ch/hauptrubrik-2/seen-fluesse/badewasserqualitaet.html/6238',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Schwimmbad Arbon'}},
#   {'type': 'Feature',
#    'featureId': 'CH20006',
#    'bbox': [9.291517, 47.613574, 9.291517, 47.613574],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH20006',
#    'geometry': {'type': 'Point', 'coordinates': [9.291517, 47.613574]},
#    'properties': {'bwname': 'Strandbad Güttingen',
#     'groupid': None,
#     'nwunitname': 'Bodensee',
#     'gemeinde': 'Güttingen',
#     'canton': 'TG',
#     'bwatercat': 'See',
#     'url': 'https://kantlab.tg.ch/hauptrubrik-2/seen-fluesse/badewasserqualitaet.html/6238',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Strandbad Güttingen'}},
#   {'type': 'Feature',
#    'featureId': 'CH20009',
#    'bbox': [9.200814, 47.646473, 9.200814, 47.646473],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH20009',
#    'geometry': {'type': 'Point', 'coordinates': [9.200814, 47.646473]},
#    'properties': {'bwname': 'Schwimmbad Hörnli',
#     'groupid': None,
#     'nwunitname': 'Bodensee',
#     'gemeinde': 'Kreuzlingen',
#     'canton': 'TG',
#     'bwatercat': 'See',
#     'url': 'https://kantlab.tg.ch/hauptrubrik-2/seen-fluesse/badewasserqualitaet.html/6238',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Schwimmbad Hörnli'}},
#   {'type': 'Feature',
#    'featureId': 'CH20013',
#    'bbox': [9.377825, 47.572579, 9.377825, 47.572579],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH20013',
#    'geometry': {'type': 'Point', 'coordinates': [9.377825, 47.572579]},
#    'properties': {'bwname': 'Schwimmbad Romanshorn',
#     'groupid': None,
#     'nwunitname': 'Bodensee',
#     'gemeinde': 'Romanshorn',
#     'canton': 'TG',
#     'bwatercat': 'See',
#     'url': 'https://kantlab.tg.ch/hauptrubrik-2/seen-fluesse/badewasserqualitaet.html/6238',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Schwimmbad Romanshorn'}},
#   {'type': 'Feature',
#    'featureId': 'CH20025',
#    'bbox': [8.755956, 47.689251, 8.755956, 47.689251],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH20025',
#    'geometry': {'type': 'Point', 'coordinates': [8.755956, 47.689251]},
#    'properties': {'bwname': 'Rodenbrunen',
#     'groupid': None,
#     'nwunitname': 'Hochrhein',
#     'gemeinde': 'Diessenhofen',
#     'canton': 'TG',
#     'bwatercat': 'Fluss',
#     'url': 'https://kantlab.tg.ch/hauptrubrik-2/seen-fluesse/badewasserqualitaet.html/6238',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Rodenbrunen'}},
#   {'type': 'Feature',
#    'featureId': 'CH20035',
#    'bbox': [9.073774, 47.67082, 9.073774, 47.67082],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH20035',
#    'geometry': {'type': 'Point', 'coordinates': [9.073774, 47.67082]},
#    'properties': {'bwname': 'Seebad',
#     'groupid': None,
#     'nwunitname': 'Untersee',
#     'gemeinde': 'Ermatingen',
#     'canton': 'TG',
#     'bwatercat': 'See',
#     'url': 'https://kantlab.tg.ch/hauptrubrik-2/seen-fluesse/badewasserqualitaet.html/6238',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Seebad'}},
#   {'type': 'Feature',
#    'featureId': 'CH20041',
#    'bbox': [8.971585, 47.660071, 8.971585, 47.660071],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH20041',
#    'geometry': {'type': 'Point', 'coordinates': [8.971585, 47.660071]},
#    'properties': {'bwname': 'Strandbad Steckborn',
#     'groupid': None,
#     'nwunitname': 'Untersee',
#     'gemeinde': 'Steckborn',
#     'canton': 'TG',
#     'bwatercat': 'See',
#     'url': 'https://kantlab.tg.ch/hauptrubrik-2/seen-fluesse/badewasserqualitaet.html/6238',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Strandbad Steckborn'}},
#   {'type': 'Feature',
#    'featureId': 'CH2031',
#    'bbox': [6.939344, 46.99135, 6.939344, 46.99135],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH2031',
#    'geometry': {'type': 'Point', 'coordinates': [6.939344, 46.99135]},
#    'properties': {'bwname': 'Plage des Jeunes-Rives',
#     'groupid': None,
#     'nwunitname': 'Lac de Neuchâtel',
#     'gemeinde': 'Neuchâtel',
#     'canton': 'NE',
#     'bwatercat': 'See',
#     'url': 'https://www.ne.ch/autorites/DDTE/SCAV/eau/Pages/plages.aspx',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '0',
#     'label': 'Plage des Jeunes-Rives'}},
#   {'type': 'Feature',
#    'featureId': 'CH2032',
#    'bbox': [6.96286, 47.003432, 6.96286, 47.003432],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH2032',
#    'geometry': {'type': 'Point', 'coordinates': [6.96286, 47.003432]},
#    'properties': {'bwname': 'Plage des Enfants',
#     'groupid': None,
#     'nwunitname': 'Lac de Neuchâtel',
#     'gemeinde': 'Neuchâtel',
#     'canton': 'NE',
#     'bwatercat': 'See',
#     'url': 'https://www.ne.ch/autorites/DDTE/SCAV/eau/Pages/plages.aspx',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '0',
#     'label': 'Plage des Enfants'}},
#   {'type': 'Feature',
#    'featureId': 'CH2033',
#    'bbox': [6.873385, 46.966828, 6.873385, 46.966828],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH2033',
#    'geometry': {'type': 'Point', 'coordinates': [6.873385, 46.966828]},
#    'properties': {'bwname': 'Camping Paradis-Plage',
#     'groupid': None,
#     'nwunitname': 'Lac de Neuchâtel',
#     'gemeinde': 'Milvignes',
#     'canton': 'NE',
#     'bwatercat': 'See',
#     'url': 'https://www.ne.ch/autorites/DDTE/SCAV/eau/Pages/plages.aspx',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '0',
#     'label': 'Camping Paradis-Plage'}},
#   {'type': 'Feature',
#    'featureId': 'CH2034',
#    'bbox': [6.773908, 46.890857, 6.773908, 46.890857],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH2034',
#    'geometry': {'type': 'Point', 'coordinates': [6.773908, 46.890857]},
#    'properties': {'bwname': 'Plage de Saint-Aubin',
#     'groupid': None,
#     'nwunitname': 'Lac de Neuchâtel',
#     'gemeinde': 'La Grande Béroche',
#     'canton': 'NE',
#     'bwatercat': 'See',
#     'url': 'https://www.ne.ch/autorites/DDTE/SCAV/eau/Pages/plages.aspx',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '0',
#     'label': 'Plage de Saint-Aubin'}},
#   {'type': 'Feature',
#    'featureId': 'CH2035',
#    'bbox': [6.981512, 47.010471, 6.981512, 47.010471],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH2035',
#    'geometry': {'type': 'Point', 'coordinates': [6.981512, 47.010471]},
#    'properties': {'bwname': 'Plage de Saint-Blaise Ouest',
#     'groupid': None,
#     'nwunitname': 'Lac de Neuchâtel',
#     'gemeinde': 'Saint-Blaise',
#     'canton': 'NE',
#     'bwatercat': 'See',
#     'url': 'https://www.ne.ch/autorites/DDTE/SCAV/eau/Pages/plages.aspx',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '0',
#     'label': 'Plage de Saint-Blaise Ouest'}},
#   {'type': 'Feature',
#    'featureId': 'CH2036',
#    'bbox': [7.020149, 47.003782, 7.020149, 47.003782],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH2036',
#    'geometry': {'type': 'Point', 'coordinates': [7.020149, 47.003782]},
#    'properties': {'bwname': 'Plage de la Tène',
#     'groupid': None,
#     'nwunitname': 'Lac de Neuchâtel',
#     'gemeinde': 'La Tène',
#     'canton': 'NE',
#     'bwatercat': 'See',
#     'url': 'https://www.ne.ch/autorites/DDTE/SCAV/eau/Pages/plages.aspx',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '0',
#     'label': 'Plage de la Tène'}},
#   {'type': 'Feature',
#    'featureId': 'CH21001',
#    'bbox': [8.80701, 46.012763, 8.80701, 46.012763],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21001',
#    'geometry': {'type': 'Point', 'coordinates': [8.80701, 46.012763]},
#    'properties': {'bwname': 'Laghetto di Astano',
#     'groupid': None,
#     'nwunitname': 'Astano',
#     'gemeinde': 'Astano',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21001.jpg',
#     'year_bw': 2022,
#     'qualitaet': '0',
#     'label': 'Laghetto di Astano'}},
#   {'type': 'Feature',
#    'featureId': 'CH21002',
#    'bbox': [8.899276, 45.99218, 8.899276, 45.99218],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21002',
#    'geometry': {'type': 'Point', 'coordinates': [8.899276, 45.99218]},
#    'properties': {'bwname': 'Lido comunale Agno',
#     'groupid': 'CHGOLFOAGNO2',
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Agno',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21002.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Lido comunale Agno'}},
#   {'type': 'Feature',
#    'featureId': 'CH21003',
#    'bbox': [8.905245, 45.99382, 8.905245, 45.99382],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21003',
#    'geometry': {'type': 'Point', 'coordinates': [8.905245, 45.99382]},
#    'properties': {'bwname': 'Campeggio La Palma',
#     'groupid': 'CHGOLFOAGNO1',
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Agno',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21003.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Campeggio La Palma'}},
#   {'type': 'Feature',
#    'featureId': 'CH21004',
#    'bbox': [8.902857, 45.992862, 8.902857, 45.992862],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21004',
#    'geometry': {'type': 'Point', 'coordinates': [8.902857, 45.992862]},
#    'properties': {'bwname': 'Campeggio Molinazzo',
#     'groupid': 'CHGOLFOAGNO1',
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Agno',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21004.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Campeggio Molinazzo'}},
#   {'type': 'Feature',
#    'featureId': 'CH21006',
#    'bbox': [8.901058, 45.991725, 8.901058, 45.991725],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21006',
#    'geometry': {'type': 'Point', 'coordinates': [8.901058, 45.991725]},
#    'properties': {'bwname': 'Bagno pubblico Agno',
#     'groupid': 'CHGOLFOAGNO2',
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Agno',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21006.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Bagno pubblico Agno'}},
#   {'type': 'Feature',
#    'featureId': 'CH21007',
#    'bbox': [8.901525, 45.952735, 8.901525, 45.952735],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21007',
#    'geometry': {'type': 'Point', 'coordinates': [8.901525, 45.952735]},
#    'properties': {'bwname': 'Lido Càsoro',
#     'groupid': None,
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Barbengo',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21007.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Lido Càsoro'}},
#   {'type': 'Feature',
#    'featureId': 'CH21009',
#    'bbox': [8.920181, 45.915261, 8.920181, 45.915261],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21009',
#    'geometry': {'type': 'Point', 'coordinates': [8.920181, 45.915261]},
#    'properties': {'bwname': 'Albergo Zappa',
#     'groupid': None,
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Brusino Arsizio',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21009.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Albergo Zappa'}},
#   {'type': 'Feature',
#    'featureId': 'CH21011',
#    'bbox': [8.978775, 45.90553, 8.978775, 45.90553],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21011',
#    'geometry': {'type': 'Point', 'coordinates': [8.978775, 45.90553]},
#    'properties': {'bwname': 'Ristorante Lido Capolago',
#     'groupid': None,
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Capolago',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21011.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Ristorante Lido Capolago'}},
#   {'type': 'Feature',
#    'featureId': 'CH21012',
#    'bbox': [8.887379, 45.970894, 8.887379, 45.970894],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21012',
#    'geometry': {'type': 'Point', 'coordinates': [8.887379, 45.970894]},
#    'properties': {'bwname': 'Bagno Spiaggia Caslano',
#     'groupid': None,
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Caslano',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21012.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Bagno Spiaggia Caslano'}},
#   {'type': 'Feature',
#    'featureId': 'CH21013',
#    'bbox': [8.893096, 45.972403, 8.893096, 45.972403],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21013',
#    'geometry': {'type': 'Point', 'coordinates': [8.893096, 45.972403]},
#    'properties': {'bwname': 'Foce Magliasina',
#     'groupid': None,
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Caslano',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21013.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Foce Magliasina'}},
#   {'type': 'Feature',
#    'featureId': 'CH21014',
#    'bbox': [8.992914, 46.003647, 8.992914, 46.003647],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21014',
#    'geometry': {'type': 'Point', 'coordinates': [8.992914, 46.003647]},
#    'properties': {'bwname': 'Albergo Elvezia al Lago',
#     'groupid': 'CHGANDRIA2',
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Lugano',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21014.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Albergo Elvezia al Lago'}},
#   {'type': 'Feature',
#    'featureId': 'CH21015',
#    'bbox': [8.968814, 46.005192, 8.968814, 46.005192],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21015',
#    'geometry': {'type': 'Point', 'coordinates': [8.968814, 46.005192]},
#    'properties': {'bwname': 'Albergo Villa Castagnola',
#     'groupid': 'CHCASSARATE',
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Lugano',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21015.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Albergo Villa Castagnola'}},
#   {'type': 'Feature',
#    'featureId': 'CH21016',
#    'bbox': [8.947629, 45.995446, 8.947629, 45.995446],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21016',
#    'geometry': {'type': 'Point', 'coordinates': [8.947629, 45.995446]},
#    'properties': {'bwname': 'Bagno Pubblico Riva Caccia',
#     'groupid': None,
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Lugano',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21016.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Bagno Pubblico Riva Caccia'}},
#   {'type': 'Feature',
#    'featureId': 'CH21018',
#    'bbox': [8.967989, 46.005221, 8.967989, 46.005221],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21018',
#    'geometry': {'type': 'Point', 'coordinates': [8.967989, 46.005221]},
#    'properties': {'bwname': 'Hotel Lido Seegarten',
#     'groupid': 'CHCASSARATE',
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Lugano',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21018.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Hotel Lido Seegarten'}},
#   {'type': 'Feature',
#    'featureId': 'CH21019',
#    'bbox': [8.963984, 46.004232, 8.963984, 46.004232],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21019',
#    'geometry': {'type': 'Point', 'coordinates': [8.963984, 46.004232]},
#    'properties': {'bwname': 'Lido Bagno Spiaggia Lugano',
#     'groupid': None,
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Lugano',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21019.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Lido Bagno Spiaggia Lugano'}},
#   {'type': 'Feature',
#    'featureId': 'CH21020',
#    'bbox': [8.98955, 46.002011, 8.98955, 46.002011],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21020',
#    'geometry': {'type': 'Point', 'coordinates': [8.98955, 46.002011]},
#    'properties': {'bwname': 'Lido San Domenico',
#     'groupid': 'CHGANDRIA2',
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Lugano',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21020.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Lido San Domenico'}},
#   {'type': 'Feature',
#    'featureId': 'CH21021',
#    'bbox': [9.0148, 45.998331, 9.0148, 45.998331],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21021',
#    'geometry': {'type': 'Point', 'coordinates': [9.0148, 45.998331]},
#    'properties': {'bwname': 'Spiaggia delle Cantine',
#     'groupid': None,
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Lugano',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21021.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Spiaggia delle Cantine'}},
#   {'type': 'Feature',
#    'featureId': 'CH21022',
#    'bbox': [8.98533, 45.987953, 8.98533, 45.987953],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21022',
#    'geometry': {'type': 'Point', 'coordinates': [8.98533, 45.987953]},
#    'properties': {'bwname': 'Ostello della Gioventù',
#     'groupid': None,
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Lugano (Caprino)',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21022.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Ostello della Gioventù'}},
#   {'type': 'Feature',
#    'featureId': 'CH21023',
#    'bbox': [8.895142, 45.979943, 8.895142, 45.979943],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21023',
#    'geometry': {'type': 'Point', 'coordinates': [8.895142, 45.979943]},
#    'properties': {'bwname': 'Bagno spiaggia Magliaso',
#     'groupid': 'CHMAGLIASO_2021',
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Magliaso',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21023.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Bagno spiaggia Magliaso'}},
#   {'type': 'Feature',
#    'featureId': 'CH21025',
#    'bbox': [8.895053, 45.975635, 8.895053, 45.975635],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21025',
#    'geometry': {'type': 'Point', 'coordinates': [8.895053, 45.975635]},
#    'properties': {'bwname': 'Evangelisches Zentrum',
#     'groupid': 'CHMAGLIASO_2021',
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Magliaso',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21025.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Evangelisches Zentrum'}},
#   {'type': 'Feature',
#    'featureId': 'CH21026',
#    'bbox': [8.894752, 45.980785, 8.894752, 45.980785],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21026',
#    'geometry': {'type': 'Point', 'coordinates': [8.894752, 45.980785]},
#    'properties': {'bwname': 'Stiftung Zuercher Ferienkolonien',
#     'groupid': 'CHMAGLIASO_2021',
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Magliaso',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21026.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Stiftung Zuercher Ferienkolonien'}},
#   {'type': 'Feature',
#    'featureId': 'CH21027',
#    'bbox': [8.96772, 45.93332, 8.96772, 45.93332],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21027',
#    'geometry': {'type': 'Point', 'coordinates': [8.96772, 45.93332]},
#    'properties': {'bwname': 'Lido Comunale Maroggia',
#     'groupid': None,
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Maroggia',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21027.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Lido Comunale Maroggia'}},
#   {'type': 'Feature',
#    'featureId': 'CH21028',
#    'bbox': [8.977845, 45.92378, 8.977845, 45.92378],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21028',
#    'geometry': {'type': 'Point', 'coordinates': [8.977845, 45.92378]},
#    'properties': {'bwname': 'Campeggio Paradiso',
#     'groupid': 'CHMELANO',
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Melano',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21028.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Campeggio Paradiso'}},
#   {'type': 'Feature',
#    'featureId': 'CH21029',
#    'bbox': [8.975551, 45.927482, 8.975551, 45.927482],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21029',
#    'geometry': {'type': 'Point', 'coordinates': [8.975551, 45.927482]},
#    'properties': {'bwname': 'Campeggio Monte Generoso',
#     'groupid': 'CHMELANO',
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Melano',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21029.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Campeggio Monte Generoso'}},
#   {'type': 'Feature',
#    'featureId': 'CH21031',
#    'bbox': [8.981066, 45.920532, 8.981066, 45.920532],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21031',
#    'geometry': {'type': 'Point', 'coordinates': [8.981066, 45.920532]},
#    'properties': {'bwname': 'Lido Comunale Melano',
#     'groupid': 'CHMELANO',
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Melano',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21031.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Lido Comunale Melano'}},
#   {'type': 'Feature',
#    'featureId': 'CH21033',
#    'bbox': [8.942726, 45.950473, 8.942726, 45.950473],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21033',
#    'geometry': {'type': 'Point', 'coordinates': [8.942726, 45.950473]},
#    'properties': {'bwname': 'Albergo Battello',
#     'groupid': 'CHMELIDE',
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Melide',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21033.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Albergo Battello'}},
#   {'type': 'Feature',
#    'featureId': 'CH21034',
#    'bbox': [8.943637, 45.951252, 8.943637, 45.951252],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21034',
#    'geometry': {'type': 'Point', 'coordinates': [8.943637, 45.951252]},
#    'properties': {'bwname': 'Albergo Del Lago',
#     'groupid': 'CHMELIDE',
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Melide',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21034.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Albergo Del Lago'}},
#   {'type': 'Feature',
#    'featureId': 'CH21035',
#    'bbox': [8.944222, 45.951415, 8.944222, 45.951415],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21035',
#    'geometry': {'type': 'Point', 'coordinates': [8.944222, 45.951415]},
#    'properties': {'bwname': 'Albergo Riviera',
#     'groupid': 'CHMELIDE',
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Melide',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21035.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Albergo Riviera'}},
#   {'type': 'Feature',
#    'featureId': 'CH21036',
#    'bbox': [8.948839, 45.952316, 8.948839, 45.952316],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21036',
#    'geometry': {'type': 'Point', 'coordinates': [8.948839, 45.952316]},
#    'properties': {'bwname': 'Lido Comunale Melide',
#     'groupid': None,
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Melide',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21036.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Lido Comunale Melide'}},
#   {'type': 'Feature',
#    'featureId': 'CH21040',
#    'bbox': [8.907192, 45.926947, 8.907192, 45.926947],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21040',
#    'geometry': {'type': 'Point', 'coordinates': [8.907192, 45.926947]},
#    'properties': {'bwname': 'Hotel Ristorante Arbostora',
#     'groupid': None,
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Morcote',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21040.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Hotel Ristorante Arbostora'}},
#   {'type': 'Feature',
#    'featureId': 'CH21042',
#    'bbox': [8.900425, 45.930868, 8.900425, 45.930868],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21042',
#    'geometry': {'type': 'Point', 'coordinates': [8.900425, 45.930868]},
#    'properties': {'bwname': 'Lido Ristorante al Porto',
#     'groupid': None,
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Morcote',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21042.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Lido Ristorante al Porto'}},
#   {'type': 'Feature',
#    'featureId': 'CH21043',
#    'bbox': [8.908761, 45.993532, 8.908761, 45.993532],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21043',
#    'geometry': {'type': 'Point', 'coordinates': [8.908761, 45.993532]},
#    'properties': {'bwname': 'Campeggio Touring Club',
#     'groupid': 'CHGOLFOAGNO1',
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Muzzano',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21043.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Campeggio Touring Club'}},
#   {'type': 'Feature',
#    'featureId': 'CH21046',
#    'bbox': [8.955183, 45.989479, 8.955183, 45.989479],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21046',
#    'geometry': {'type': 'Point', 'coordinates': [8.955183, 45.989479]},
#    'properties': {'bwname': "Lido Comunale Conca d'Oro",
#     'groupid': None,
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Paradiso',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21046.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': "Lido Comunale Conca d'Oro"}},
#   {'type': 'Feature',
#    'featureId': 'CH21047',
#    'bbox': [8.861721, 45.969647, 8.861721, 45.969647],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21047',
#    'geometry': {'type': 'Point', 'coordinates': [8.861721, 45.969647]},
#    'properties': {'bwname': 'Albergo Tresa Bay',
#     'groupid': None,
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Ponte Tresa',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21047.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Albergo Tresa Bay'}},
#   {'type': 'Feature',
#    'featureId': 'CH21048',
#    'bbox': [8.974719, 45.907034, 8.974719, 45.907034],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21048',
#    'geometry': {'type': 'Point', 'coordinates': [8.974719, 45.907034]},
#    'properties': {'bwname': 'Lido Comunale Riva S. Vitale',
#     'groupid': None,
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Riva S. Vitale',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21048.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Lido Comunale Riva S. Vitale'}},
#   {'type': 'Feature',
#    'featureId': 'CH21049',
#    'bbox': [8.929865, 45.932434, 8.929865, 45.932434],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH21049',
#    'geometry': {'type': 'Point', 'coordinates': [8.929865, 45.932434]},
#    'properties': {'bwname': 'Swiss Diamond Hotel',
#     'groupid': None,
#     'nwunitname': 'Ceresio',
#     'gemeinde': 'Vico Morcote',
#     'canton': 'TI',
#     'bwatercat': 'See',
#     'url': 'https://www4.ti.ch/dss/dsp/lc/home/',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH21049.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Swiss Diamond Hotel'}},
#   {'type': 'Feature',
#    'featureId': 'CH21050',
# ...
#     'bwatercat': 'See',
#     'url': 'https://www.ge.ch/dossier/acces-publics-au-lac-baignade-eaux-vives/qualite-eau-plages',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Vengeron (centre)'}},
#   {'type': 'Feature',
#    'featureId': 'CH25024',
#    'bbox': [6.154456, 46.253408, 6.154456, 46.253408],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH25024',
#    'geometry': {'type': 'Point', 'coordinates': [6.154456, 46.253408]},
#    'properties': {'bwname': 'Bellevue Port Gitana',
#     'groupid': None,
#     'nwunitname': 'Le Léman',
#     'gemeinde': 'Bellevue',
#     'canton': 'GE',
#     'bwatercat': 'See',
#     'url': 'https://www.ge.ch/dossier/acces-publics-au-lac-baignade-eaux-vives/qualite-eau-plages',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Bellevue Port Gitana'}},
#   {'type': 'Feature',
#    'featureId': 'CH25025',
#    'bbox': [6.159114, 46.259947, 6.159114, 46.259947],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH25025',
#    'geometry': {'type': 'Point', 'coordinates': [6.159114, 46.259947]},
#    'properties': {'bwname': 'Bains de Saugy',
#     'groupid': None,
#     'nwunitname': 'Le Léman',
#     'gemeinde': 'Genthod',
#     'canton': 'GE',
#     'bwatercat': 'See',
#     'url': 'https://www.ge.ch/dossier/acces-publics-au-lac-baignade-eaux-vives/qualite-eau-plages',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Bains de Saugy'}},
#   {'type': 'Feature',
#    'featureId': 'CH25026',
#    'bbox': [6.16396, 46.263484, 6.16396, 46.263484],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH25026',
#    'geometry': {'type': 'Point', 'coordinates': [6.16396, 46.263484]},
#    'properties': {'bwname': 'Creux-de-Genthod aval',
#     'groupid': None,
#     'nwunitname': 'Le Léman',
#     'gemeinde': 'Genthod',
#     'canton': 'GE',
#     'bwatercat': 'See',
#     'url': 'https://www.ge.ch/dossier/acces-publics-au-lac-baignade-eaux-vives/qualite-eau-plages',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '3',
#     'label': 'Creux-de-Genthod aval'}},
#   {'type': 'Feature',
#    'featureId': 'CH25027',
#    'bbox': [6.171214, 46.273912, 6.171214, 46.273912],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH25027',
#    'geometry': {'type': 'Point', 'coordinates': [6.171214, 46.273912]},
#    'properties': {'bwname': 'La Bécassine',
#     'groupid': None,
#     'nwunitname': 'Le Léman',
#     'gemeinde': 'Versoix',
#     'canton': 'GE',
#     'bwatercat': 'See',
#     'url': 'https://www.ge.ch/dossier/acces-publics-au-lac-baignade-eaux-vives/qualite-eau-plages',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'La Bécassine'}},
#   {'type': 'Feature',
#    'featureId': 'CH25029',
#    'bbox': [6.171144, 46.28917, 6.171144, 46.28917],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH25029',
#    'geometry': {'type': 'Point', 'coordinates': [6.171144, 46.28917]},
#    'properties': {'bwname': 'Versoix plage',
#     'groupid': None,
#     'nwunitname': 'Le Léman',
#     'gemeinde': 'Versoix',
#     'canton': 'GE',
#     'bwatercat': 'See',
#     'url': 'https://www.ge.ch/dossier/acces-publics-au-lac-baignade-eaux-vives/qualite-eau-plages',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '2',
#     'label': 'Versoix plage'}},
#   {'type': 'Feature',
#    'featureId': 'CH25030',
#    'bbox': [6.208735, 46.348442, 6.208735, 46.348442],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH25030',
#    'geometry': {'type': 'Point', 'coordinates': [6.208735, 46.348442]},
#    'properties': {'bwname': 'Céligny plage',
#     'groupid': None,
#     'nwunitname': 'Le Léman',
#     'gemeinde': 'Céligny',
#     'canton': 'GE',
#     'bwatercat': 'See',
#     'url': 'https://www.ge.ch/dossier/acces-publics-au-lac-baignade-eaux-vives/qualite-eau-plages',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '2',
#     'label': 'Céligny plage'}},
#   {'type': 'Feature',
#    'featureId': 'CH25031',
#    'bbox': [6.131008, 46.202738, 6.131008, 46.202738],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH25031',
#    'geometry': {'type': 'Point', 'coordinates': [6.131008, 46.202738]},
#    'properties': {'bwname': 'Rhône pont Sous-Terre RG',
#     'groupid': None,
#     'nwunitname': 'Rhône Unterlauf',
#     'gemeinde': 'Genève',
#     'canton': 'GE',
#     'bwatercat': 'Fluss',
#     'url': 'https://www.ge.ch/dossier/acces-publics-au-lac-baignade-eaux-vives/qualite-eau-plages',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH25031.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Rhône pont Sous-Terre RG'}},
#   {'type': 'Feature',
#    'featureId': 'CH25033',
#    'bbox': [6.153222, 46.220043, 6.153222, 46.220043],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH25033',
#    'geometry': {'type': 'Point', 'coordinates': [6.153222, 46.220043]},
#    'properties': {'bwname': 'Perle du lac',
#     'groupid': None,
#     'nwunitname': 'Le Léman',
#     'gemeinde': 'Genève',
#     'canton': 'GE',
#     'bwatercat': 'See',
#     'url': 'https://www.ge.ch/dossier/acces-publics-au-lac-baignade-eaux-vives/qualite-eau-plages',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH25033.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Perle du lac'}},
#   {'type': 'Feature',
#    'featureId': 'CH25034',
#    'bbox': [6.130714, 46.203644, 6.130714, 46.203644],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH25034',
#    'geometry': {'type': 'Point', 'coordinates': [6.130714, 46.203644]},
#    'properties': {'bwname': 'Rhône Pont-sous-Terre RD',
#     'groupid': None,
#     'nwunitname': 'Rhône Unterlauf',
#     'gemeinde': 'Genève',
#     'canton': 'GE',
#     'bwatercat': 'Fluss',
#     'url': 'https://www.ge.ch/dossier/acces-publics-au-lac-baignade-eaux-vives/qualite-eau-plages',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Rhône Pont-sous-Terre RD'}},
#   {'type': 'Feature',
#    'featureId': 'CH25035',
#    'bbox': [5.993489, 46.177866, 5.993489, 46.177866],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH25035',
#    'geometry': {'type': 'Point', 'coordinates': [5.993489, 46.177866]},
#    'properties': {'bwname': 'Etang de la Plaine',
#     'groupid': None,
#     'nwunitname': 'Rhône Unterlauf',
#     'gemeinde': 'Dardagny',
#     'canton': 'GE',
#     'bwatercat': 'Fluss',
#     'url': 'https://www.ge.ch/dossier/acces-publics-au-lac-baignade-eaux-vives/qualite-eau-plages',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Etang de la Plaine'}},
#   {'type': 'Feature',
#    'featureId': 'CH25036',
#    'bbox': [6.165895, 46.210767, 6.165895, 46.210767],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH25036',
#    'geometry': {'type': 'Point', 'coordinates': [6.165895, 46.210767]},
#    'properties': {'bwname': 'Plage des Eaux-Vives',
#     'groupid': None,
#     'nwunitname': 'Le Léman',
#     'gemeinde': 'Gologny',
#     'canton': 'GE',
#     'bwatercat': 'See',
#     'url': 'https://www.ge.ch/dossier/acces-publics-au-lac-baignade-eaux-vives/qualite-eau-plages',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Plage des Eaux-Vives'}},
#   {'type': 'Feature',
#    'featureId': 'CH25037',
#    'bbox': [6.149744, 46.225716, 6.149744, 46.225716],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH25037',
#    'geometry': {'type': 'Point', 'coordinates': [6.149744, 46.225716]},
#    'properties': {'bwname': 'William-Rappard',
#     'groupid': None,
#     'nwunitname': None,
#     'gemeinde': 'Genève',
#     'canton': 'GE',
#     'bwatercat': 'See',
#     'url': 'https://www.ge.ch/dossier/acces-publics-au-lac-baignade-eaux-vives/qualite-eau-plages',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '0',
#     'label': 'William-Rappard'}},
#   {'type': 'Feature',
#    'featureId': 'CH3001',
#    'bbox': [8.420164, 47.028835, 8.420164, 47.028835],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH3001',
#    'geometry': {'type': 'Point', 'coordinates': [8.420164, 47.028835]},
#    'properties': {'bwname': 'Strandbad-Lido, Weggis',
#     'groupid': 'CHVWS',
#     'nwunitname': 'Vierwaldstättersee',
#     'gemeinde': 'Weggis',
#     'canton': 'LU',
#     'bwatercat': 'See',
#     'url': 'https://www.sz.ch/behoerden/umwelt-natur-landschaft/gewaesser/interne-links/vierwaldstaettersee.html/72-416-397-394-3822-3818',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Strandbad-Lido, Weggis'}},
#   {'type': 'Feature',
#    'featureId': 'CH3004',
#    'bbox': [8.321403, 47.04654, 8.321403, 47.04654],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH3004',
#    'geometry': {'type': 'Point', 'coordinates': [8.321403, 47.04654]},
#    'properties': {'bwname': 'Ufschötti, Luzern',
#     'groupid': 'CHVWS',
#     'nwunitname': 'Vierwaldstättersee',
#     'gemeinde': 'Luzern',
#     'canton': 'LU',
#     'bwatercat': 'See',
#     'url': 'https://www.sz.ch/behoerden/umwelt-natur-landschaft/gewaesser/interne-links/vierwaldstaettersee.html/72-416-397-394-3822-3818',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Ufschötti, Luzern'}},
#   {'type': 'Feature',
#    'featureId': 'CH4010',
#    'bbox': [8.607937, 46.897441, 8.607937, 46.897441],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH4010',
#    'geometry': {'type': 'Point', 'coordinates': [8.607937, 46.897441]},
#    'properties': {'bwname': 'Badeplatz Mississippi (Ufer 1)',
#     'groupid': 'CHVWS',
#     'nwunitname': 'Vierwaldstättersee',
#     'gemeinde': 'Seedorf',
#     'canton': 'UR',
#     'bwatercat': 'See',
#     'url': 'https://www.sz.ch/behoerden/umwelt-natur-landschaft/gewaesser/interne-links/vierwaldstaettersee.html/72-416-397-394-3822-3818',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Badeplatz Mississippi (Ufer 1)'}},
#   {'type': 'Feature',
#    'featureId': 'CH5002',
#    'bbox': [8.598231, 46.995148, 8.598231, 46.995148],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH5002',
#    'geometry': {'type': 'Point', 'coordinates': [8.598231, 46.995148]},
#    'properties': {'bwname': 'Lido Brunnen, SZ/02',
#     'groupid': 'CHVWS',
#     'nwunitname': 'Vierwaldstättersee',
#     'gemeinde': 'Ingenbohl',
#     'canton': 'SZ',
#     'bwatercat': 'See',
#     'url': 'https://www.sz.ch/behoerden/umwelt-natur-landschaft/gewaesser/interne-links/vierwaldstaettersee.html/72-416-397-394-3822-3818',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH5002.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Lido Brunnen, SZ/02'}},
#   {'type': 'Feature',
#    'featureId': 'CH6001',
#    'bbox': [8.283139, 46.954137, 8.283139, 46.954137],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH6001',
#    'geometry': {'type': 'Point', 'coordinates': [8.283139, 46.954137]},
#    'properties': {'bwname': 'Badeplatz Alpnachstad',
#     'groupid': 'CHVWS',
#     'nwunitname': 'Vierwaldstättersee',
#     'gemeinde': 'Alpnach',
#     'canton': 'OW',
#     'bwatercat': 'See',
#     'url': 'https://www.sz.ch/behoerden/umwelt-natur-landschaft/gewaesser/interne-links/vierwaldstaettersee.html/72-416-397-394-3822-3818',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Badeplatz Alpnachstad'}},
#   {'type': 'Feature',
#    'featureId': 'CH7005',
#    'bbox': [8.417998, 46.981527, 8.417998, 46.981527],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH7005',
#    'geometry': {'type': 'Point', 'coordinates': [8.417998, 46.981527]},
#    'properties': {'bwname': 'Buochs Strandbad',
#     'groupid': 'CHVWS',
#     'nwunitname': 'Vierwaldstättersee',
#     'gemeinde': 'Buochs',
#     'canton': 'NW',
#     'bwatercat': 'See',
#     'url': 'https://www.sz.ch/behoerden/umwelt-natur-landschaft/gewaesser/interne-links/vierwaldstaettersee.html/72-416-397-394-3822-3818',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Buochs Strandbad'}},
#   {'type': 'Feature',
#    'featureId': 'CH9001',
#    'bbox': [8.512601, 47.164293, 8.512601, 47.164293],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH9001',
#    'geometry': {'type': 'Point', 'coordinates': [8.512601, 47.164293]},
#    'properties': {'bwname': 'Strandbad Seeliken',
#     'groupid': None,
#     'nwunitname': 'Zuger See',
#     'gemeinde': 'Zug',
#     'canton': 'ZG',
#     'bwatercat': 'See',
#     'url': 'https://www.zg.ch/behoerden/gesundheitsdirektion/amt-fuer-verbraucherschutz/lebensmittelkontrolle/wasser/badewasser',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH9001.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Strandbad Seeliken'}},
#   {'type': 'Feature',
#    'featureId': 'CH9002',
#    'bbox': [8.4953, 47.176508, 8.4953, 47.176508],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH9002',
#    'geometry': {'type': 'Point', 'coordinates': [8.4953, 47.176508]},
#    'properties': {'bwname': 'Strandbad Brüggli',
#     'groupid': None,
#     'nwunitname': 'Zuger See',
#     'gemeinde': 'Zug',
#     'canton': 'ZG',
#     'bwatercat': 'See',
#     'url': 'https://www.zg.ch/behoerden/gesundheitsdirektion/amt-fuer-verbraucherschutz/lebensmittelkontrolle/wasser/badewasser',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH9002.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Strandbad Brüggli'}},
#   {'type': 'Feature',
#    'featureId': 'CH9003',
#    'bbox': [8.598468, 47.127836, 8.598468, 47.127836],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH9003',
#    'geometry': {'type': 'Point', 'coordinates': [8.598468, 47.127836]},
#    'properties': {'bwname': 'Camping Unterägeri',
#     'groupid': 'CH9003-04',
#     'nwunitname': 'Ägerisee',
#     'gemeinde': 'Unterägeri',
#     'canton': 'ZG',
#     'bwatercat': 'See',
#     'url': 'https://www.zg.ch/behoerden/gesundheitsdirektion/amt-fuer-verbraucherschutz/lebensmittelkontrolle/wasser/badewasser',
#     'baquaimg': 'https://data.geo.admin.ch/ch.bafu.gewaesserschutz-badewasserqualitaet/image/CH9003.jpg',
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Camping Unterägeri'}},
#   {'type': 'Feature',
#    'featureId': 'CH9004',
#    'bbox': [8.610627, 47.132913, 8.610627, 47.132913],
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet',
#    'layerName': 'Badegewässerqualität',
#    'id': 'CH9004',
#    'geometry': {'type': 'Point', 'coordinates': [8.610627, 47.132913]},
#    'properties': {'bwname': 'Strandbad Lido',
#     'groupid': 'CH9003-04',
#     'nwunitname': 'Ägerisee',
#     'gemeinde': 'Oberägeri',
#     'canton': 'ZG',
#     'bwatercat': 'See',
#     'url': 'https://www.zg.ch/behoerden/gesundheitsdirektion/amt-fuer-verbraucherschutz/lebensmittelkontrolle/wasser/badewasser',
#     'baquaimg': None,
#     'year_bw': 2022,
#     'qualitaet': '1',
#     'label': 'Strandbad Lido'}}]}

# %%
df = pd.json_normalize(response.json()['results'])\
.rename(columns={
    'properties.bwname': 'name',
    'properties.label': 'alternate_name'
})\
.drop(
    columns=[
        'type', 'featureId', 'bbox', 'layerBodId', 'layerName',
        'geometry.type', 'properties.groupid', 'properties.nwunitname', 'properties.gemeinde', 'properties.bwatercat',
        'properties.canton', 'properties.url', 'properties.baquaimg', 'properties.year_bw', 'properties.qualitaet'
    ]
)\
.set_index('id')

# %%
# Split coordinates into columns
df[['long', 'lat']] = df['geometry.coordinates'].apply(pd.Series)
locations = df.drop(columns=['geometry.coordinates'])
locations
# Out:
#                        name      alternate_name      long        lat
# id
# CH10001   Plage de Gumefens   Plage de Gumefens  7.087865  46.675282
# CH10004  Gemeinde Strandbad  Gemeinde Strandbad  7.110896  46.927943
# CH10007  Plage de Portalban  Plage de Portalban  6.953375  46.922705
# CH10009      Nouvelle plage      Nouvelle plage  6.848274  46.857082
# CH1013       Strandbad Maur      Strandbad Maur  8.674674  47.345638
# ...                     ...                 ...       ...        ...
# CH7005     Buochs Strandbad    Buochs Strandbad  8.417998  46.981527
# CH9001   Strandbad Seeliken  Strandbad Seeliken  8.512601  47.164293
# CH9002    Strandbad Brüggli   Strandbad Brüggli  8.495300  47.176508
# CH9003   Camping Unterägeri  Camping Unterägeri  8.598468  47.127836
# CH9004       Strandbad Lido      Strandbad Lido  8.610627  47.132913
#
# [196 rows x 4 columns]

# %%
db = sqlite3.connect("../dataset.sqlite3")
locations.to_sql("locations", db, if_exists="append")
# Out:
# 196
