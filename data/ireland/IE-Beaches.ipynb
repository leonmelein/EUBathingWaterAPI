# %%
import requests
import pandas as pd
import sqlite3

from shapely.geometry import Point
from geopandas import GeoDataFrame

# %%
server = "https://api.beaches.ie/api/beach/restricted/1000"

# %%
response = requests.get(server)
data = response.json()
data
# Out:
# [{'Code': 'IENWBWT220_0400_0100',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IENWBWT220_0400_0100/IENWBWT220_0400_0100_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': "Lady's Bay, Buncrana",
#   'CountyName': 'Donegal',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-15T12:39:54',
#   'EndDate': None,
#   'RestrictionTypeId': 4,
#   'RestrictionTypeName': 'Bathing is temporarily prohibited',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/b542b44d-91e6-4d48-8ba2-1f01bc87fba9.pdf'},
#  {'Code': 'IENWBWC020_0000_0100',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IENWBWC020_0000_0100/IENWBWC020_0000_0100_photo_1_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Bundoran',
#   'CountyName': 'Donegal',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-15T00:00:00',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/c1bacfd5-e506-4a4e-abc7-14cccd8fa3d8.pdf'},
#  {'Code': 'IENWBWC160_0000_0100',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IENWBWC160_0000_0100/IENWBWC160_0000_0100_photo_0_thumbnail.png',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Portarthur, Derrybeg',
#   'CountyName': 'Donegal',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-15T00:00:00',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/ae4e8cb9-9277-40ab-8d5f-b7c19f067c8d.pdf'},
#  {'Code': 'IENWBWC190_0000_0100',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IENWBWC190_0000_0100/IENWBWC190_0000_0100_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Downings',
#   'CountyName': 'Donegal',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-15T00:00:00',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/bc468b43-fb82-4518-a37f-b054f63ed1ec.pdf'},
#  {'Code': 'IENWBWC190_0000_0300',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IENWBWC190_0000_0300/IENWBWC190_0000_0300_photo_0_thumbnail.png',
#   'WaterQualityId': 1,
#   'WaterQualityName': 'Good',
#   'Name': 'Portnablagh',
#   'CountyName': 'Donegal',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-15T00:00:00',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/67e62813-ee1c-46d1-8ca8-09edc78121b4.pdf'},
#  {'Code': 'IENWBWC220_0000_0100',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IENWBWC220_0000_0100/IENWBWC220_0000_0100_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Lisfannon',
#   'CountyName': 'Donegal',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-15T00:00:00',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/7315b645-741f-4709-925c-05e1705d9dfd.pdf'},
#  {'Code': 'IENWBWC220_0000_0200',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IENWBWC220_0000_0200/IENWBWC220_0000_0200_photo_0_thumbnail.png',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Rathmullan',
#   'CountyName': 'Donegal',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-15T00:00:00',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/1c376d5a-4e1c-4328-97bf-4fd7adc74b42.pdf'},
#  {'Code': 'IESHBWC100_0000_0100',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IESHBWC100_0000_0100/IESHBWC100_0000_0100_photo_1_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Lahinch',
#   'CountyName': 'Clare',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T17:20:05',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/d3251037-adb9-459b-a963-2e1faa42c6cc.pdf'},
#  {'Code': 'IEWEBWC170_0000_0100',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IEWEBWC170_0000_0100/IEWEBWC170_0000_0100_photo_0_thumbnail.jpg',
#   'WaterQualityId': 1,
#   'WaterQualityName': 'Good',
#   'Name': 'Silverstrand Beach',
#   'CountyName': 'Galway',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T17:09:04',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/2b54e4bd-77e2-4071-bd79-9db715622b10.pdf'},
#  {'Code': 'IEWEBWT170_0700_0100',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IEWEBWT170_0700_0100/IEWEBWT170_0700_0100_photo_0_thumbnail.jpg',
#   'WaterQualityId': 1,
#   'WaterQualityName': 'Good',
#   'Name': 'Grattan Road Beach',
#   'CountyName': 'Galway',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T17:09:04',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/9b620869-f506-4328-a3d6-a61b7c882bf0.pdf'},
#  {'Code': 'IEWEBWT170_0700_0200',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IEWEBWT170_0700_0200/IEWEBWT170_0700_0200_photo_0_thumbnail.jpg',
#   'WaterQualityId': 1,
#   'WaterQualityName': 'Good',
#   'Name': 'Ballyloughane Beach',
#   'CountyName': 'Galway',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T17:09:04',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/5e2710b2-9e2b-4316-bba1-eae387a7dae1.pdf'},
#  {'Code': 'IEEABWC090_0000_0040',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IEEABWC090_0000_0040/IEEABWC090_0000_0040_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Forty Foot Bathing Place',
#   'CountyName': 'Dublin',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T16:47:25',
#   'EndDate': None,
#   'RestrictionTypeId': 4,
#   'RestrictionTypeName': 'Bathing is temporarily prohibited',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 0,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/d6923204-6b4e-48c4-b11c-055556df667b.pdf'},
#  {'Code': 'IESHBWC070_0000_0200',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IESHBWC070_0000_0200/IESHBWC070_0000_0200_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'White Strand, Miltown Malbay',
#   'CountyName': 'Clare',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T16:44:32',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/46b13321-1236-410a-8e96-744b2d5a311b.pdf'},
#  {'Code': 'IESHBWC070_0000_0300',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IESHBWC070_0000_0300/IESHBWC070_0000_0300_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Spanish Point',
#   'CountyName': 'Clare',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T16:44:32',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/e5523ad5-6e9d-4eac-b318-70a3e0056938.pdf'},
#  {'Code': 'IESHBWC070_0000_0400',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IESHBWC070_0000_0400/IESHBWC070_0000_0400_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Kilkee',
#   'CountyName': 'Clare',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T16:44:32',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/e891f588-8dbc-4efa-9c56-8f16714af3a3.pdf'},
#  {'Code': 'IESHBWC080_0000_0100',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IESHBWC080_0000_0100/IESHBWC080_0000_0100_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'White Strand, Doonbeg',
#   'CountyName': 'Clare',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T16:44:32',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/85e43029-a065-4d9f-8e3f-a3217c434579.pdf'},
#  {'Code': 'IESHBWC060_0000_0100',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IESHBWC060_0000_0100/IESHBWC060_0000_0100_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Cappagh Pier, Kilrush',
#   'CountyName': 'Clare',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T16:44:32',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/f46cc295-e04a-4799-9e04-c4e0adcbe699.pdf'},
#  {'Code': 'IEEABWC090_0000_0100',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IEEABWC090_0000_0100/IEEABWC090_0000_0100_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Seapoint',
#   'CountyName': 'Dublin',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T16:34:25',
#   'EndDate': None,
#   'RestrictionTypeId': 4,
#   'RestrictionTypeName': 'Bathing is temporarily prohibited',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 0,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/d0eb4b08-b85d-4023-8126-0f6a501a95a7.pdf'},
#  {'Code': 'BPNBF220000170001',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//BPNBF220000170001/BPNBF220000170001_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Portacloy Beach',
#   'CountyName': 'Mayo',
#   'StatusTypeId': 4,
#   'StartDate': '2023-07-14T16:04:12',
#   'EndDate': '2023-07-20T00:00:00',
#   'RestrictionTypeId': 30,
#   'RestrictionTypeName': 'Do not Swim',
#   'RestrictionGroupTypeId': 2,
#   'RestrictionGroupTypeName': 'Pollution',
#   'IncidentDescription': 'Water Quality deteriorated',
#   'IsShortTermPollution': 0,
#   'WarningNoticeUrl': None},
#  {'Code': 'IESHBWC060_0000_0200',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IESHBWC060_0000_0200/IESHBWC060_0000_0200_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Ballybunnion North ',
#   'CountyName': 'Kerry',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T15:13:07',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/02b2184f-9cbd-4f8b-8722-358dcc303cc4.pdf'},
#  {'Code': 'IESHBWC060_0000_0300',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IESHBWC060_0000_0300/IESHBWC060_0000_0300_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Ballybunnion South',
#   'CountyName': 'Kerry',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T15:13:07',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/991a4935-66c8-4d16-acba-b408782fd727.pdf'},
#  {'Code': 'IESWBWC200_0000_0100',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IESWBWC200_0000_0100/IESWBWC200_0000_0100_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Baile an Sceilg (Ballinskelligs)',
#   'CountyName': 'Kerry',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T15:13:07',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/61674440-8eb9-44cd-8b43-65383e4219c4.pdf'},
#  {'Code': 'IESWBWC200_0000_0200',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IESWBWC200_0000_0200/IESWBWC200_0000_0200_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Trá na hUíne (Inny Strand, Waterville)',
#   'CountyName': 'Kerry',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T15:13:07',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/f8854c59-395e-4819-b1ac-0fa31e147430.pdf'},
#  {'Code': 'IESWBWC220_0000_0100',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IESWBWC220_0000_0100/IESWBWC220_0000_0100_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'White Strand, Caherciveen',
#   'CountyName': 'Kerry',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T15:13:07',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/8f1fed9c-2562-42aa-b7f0-6a4afdf631ef.pdf'},
#  {'Code': 'IESWBWC230_0000_0100',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IESWBWC230_0000_0100/IESWBWC230_0000_0100_photo_0_thumbnail.jpg',
#   'WaterQualityId': 1,
#   'WaterQualityName': 'Good',
#   'Name': 'Fionntrá (Ventry)',
#   'CountyName': 'Kerry',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T15:13:07',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/dcd31316-a425-4b88-82e1-294ee8ff3efa.pdf'},
#  {'Code': 'IESWBWC230_0000_0400',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IESWBWC230_0000_0400/IESWBWC230_0000_0400_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Kells',
#   'CountyName': 'Kerry',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T15:13:07',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/5727e5dc-7759-4cef-9ba4-6abb11affa10.pdf'},
#  {'Code': 'IESWBWC230_0000_0500',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IESWBWC230_0000_0500/IESWBWC230_0000_0500_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Cúas Crom',
#   'CountyName': 'Kerry',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T15:13:07',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/fc3ec2c4-943f-4a41-8527-a8156be685c0.pdf'},
#  {'Code': 'IESHBWC040_0000_0250',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IESHBWC040_0000_0250/IESHBWC040_0000_0250_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Fenit',
#   'CountyName': 'Kerry',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T15:13:07',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/7199b2ec-9e4e-4538-9caf-7a24339b153a.pdf'},
#  {'Code': 'IESHBWC040_0000_0400',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IESHBWC040_0000_0400/IESHBWC040_0000_0400_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Maharabeg',
#   'CountyName': 'Kerry',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T15:13:07',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/88359178-abe5-4614-ba44-e61569f0266c.pdf'},
#  {'Code': 'BPNBF130000190001',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//BPNBF130000190001/BPNBF130000190001_photo_0_thumbnail.jpg',
#   'WaterQualityId': 1,
#   'WaterQualityName': 'Good',
#   'Name': 'Littor beach',
#   'CountyName': 'Kerry',
#   'StatusTypeId': 4,
#   'StartDate': '2023-07-14T15:02:16',
#   'EndDate': '2023-07-18T00:00:00',
#   'RestrictionTypeId': 31,
#   'RestrictionTypeName': 'Swimming not advised',
#   'RestrictionGroupTypeId': 2,
#   'RestrictionGroupTypeName': 'Pollution',
#   'IncidentDescription': 'Risk of deterioration of water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 0,
#   'WarningNoticeUrl': None},
#  {'Code': 'BPNBF130000200001',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//BPNBF130000200001/BPNBF130000200001_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Waterville Town Beach',
#   'CountyName': 'Kerry',
#   'StatusTypeId': 4,
#   'StartDate': '2023-07-14T15:02:16',
#   'EndDate': '2023-07-18T00:00:00',
#   'RestrictionTypeId': 31,
#   'RestrictionTypeName': 'Swimming not advised',
#   'RestrictionGroupTypeId': 2,
#   'RestrictionGroupTypeName': 'Pollution',
#   'IncidentDescription': 'Risk of deterioration of water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 0,
#   'WarningNoticeUrl': None},
#  {'Code': 'BPNBF130000210001',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//BPNBF130000210001/BPNBF130000210001_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Cromane',
#   'CountyName': 'Kerry',
#   'StatusTypeId': 4,
#   'StartDate': '2023-07-14T15:02:16',
#   'EndDate': '2023-07-18T00:00:00',
#   'RestrictionTypeId': 31,
#   'RestrictionTypeName': 'Swimming not advised',
#   'RestrictionGroupTypeId': 2,
#   'RestrictionGroupTypeName': 'Pollution',
#   'IncidentDescription': 'Risk of deterioration of water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 0,
#   'WarningNoticeUrl': None},
#  {'Code': 'BPNBF130000220001',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//BPNBF130000220001/BPNBF130000220001_photo_1_thumbnail.jpg',
#   'WaterQualityId': 1,
#   'WaterQualityName': 'Good',
#   'Name': 'Reenroe',
#   'CountyName': 'Kerry',
#   'StatusTypeId': 4,
#   'StartDate': '2023-07-14T15:02:16',
#   'EndDate': '2023-07-18T00:00:00',
#   'RestrictionTypeId': 31,
#   'RestrictionTypeName': 'Swimming not advised',
#   'RestrictionGroupTypeId': 2,
#   'RestrictionGroupTypeName': 'Pollution',
#   'IncidentDescription': 'Risk of deterioration of water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 0,
#   'WarningNoticeUrl': None},
#  {'Code': 'IESHBWL25_188_0100',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IESHBWL25_188_0100/IESHBWL25_188_0100_photo_1_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Lilliput, Lough Ennell',
#   'CountyName': 'Westmeath',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-14T00:00:00',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': None},
#  {'Code': 'IEEABWC070_0000_0200',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IEEABWC070_0000_0200/IEEABWC070_0000_0200_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Portmarnock, Velvet Strand Beach',
#   'CountyName': 'Dublin',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-13T17:21:53',
#   'EndDate': None,
#   'RestrictionTypeId': 6,
#   'RestrictionTypeName': 'Prior Warning bathing water quality may be affected',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/acd49849-609c-4975-bd8c-3d35397ffcaa.pdf'},
#  {'Code': 'IEEABWC090_0000_0050',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IEEABWC090_0000_0050/IEEABWC090_0000_0050_photo_0_thumbnail.jpg',
#   'WaterQualityId': 3,
#   'WaterQualityName': 'Poor',
#   'Name': 'Sandycove Beach',
#   'CountyName': 'Dublin',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-11T18:54:22',
#   'EndDate': None,
#   'RestrictionTypeId': 1,
#   'RestrictionTypeName': 'Bathing is advised against',
#   'RestrictionGroupTypeId': 2,
#   'RestrictionGroupTypeName': 'Pollution',
#   'IncidentDescription': 'Water quality  deteriorated due to suspected impacts from animals/birds and contamination of urban surface waters discharging into bathing water',
#   'IsShortTermPollution': 0,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/f5809ff7-c4ba-4979-b2ec-b9df5f467bb7.pdf'},
#  {'Code': 'IEEABWC020_0000_0350',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IEEABWC020_0000_0350/IEEABWC020_0000_0350_photo_0_thumbnail.jpg',
#   'WaterQualityId': 3,
#   'WaterQualityName': 'Poor',
#   'Name': 'Rush North Beach',
#   'CountyName': 'Dublin',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-11T17:00:36',
#   'EndDate': None,
#   'RestrictionTypeId': 4,
#   'RestrictionTypeName': 'Bathing is temporarily prohibited',
#   'RestrictionGroupTypeId': 2,
#   'RestrictionGroupTypeName': 'Pollution',
#   'IncidentDescription': 'Water quality  deteriorated due to suspected impacts from animals/birds and contamination of urban surface waters discharging into bathing water',
#   'IsShortTermPollution': 0,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/9edff214-76f9-4556-b7e3-d5669187f654.pdf'},
#  {'Code': 'IEEABWC090_0000_0300',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IEEABWC090_0000_0300/IEEABWC090_0000_0300_photo_0_thumbnail.jpg',
#   'WaterQualityId': 1,
#   'WaterQualityName': 'Good',
#   'Name': 'Sandymount Strand',
#   'CountyName': 'Dublin',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-10T12:08:46',
#   'EndDate': None,
#   'RestrictionTypeId': 2,
#   'RestrictionTypeName': 'Bathing is prohibited',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/9eb80a22-87c6-4b3e-bdf1-21e792891a1c.pdf'},
#  {'Code': 'IEEABWC090_0000_0400',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IEEABWC090_0000_0400/IEEABWC090_0000_0400_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Dollymount Strand',
#   'CountyName': 'Dublin',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-10T12:00:19',
#   'EndDate': None,
#   'RestrictionTypeId': 2,
#   'RestrictionTypeName': 'Bathing is prohibited',
#   'RestrictionGroupTypeId': 3,
#   'RestrictionGroupTypeName': 'Possible Pollution',
#   'IncidentDescription': 'Risk of deterioration in water quality due to expected heavy rainfall',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/a4dc283b-68b7-461e-bf45-fe2318f712fc.pdf'},
#  {'Code': 'IEEABWC100_0000_0300',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IEEABWC100_0000_0300/IEEABWC100_0000_0300_photo_1_thumbnail.jpg',
#   'WaterQualityId': 3,
#   'WaterQualityName': 'Poor',
#   'Name': 'Bray South Promenade',
#   'CountyName': 'Wicklow',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-10T00:00:00',
#   'EndDate': None,
#   'RestrictionTypeId': 4,
#   'RestrictionTypeName': 'Bathing is temporarily prohibited',
#   'RestrictionGroupTypeId': 2,
#   'RestrictionGroupTypeName': 'Pollution',
#   'IncidentDescription': 'Water quality deteriorated due to suspected storm water overflow',
#   'IsShortTermPollution': 0,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/633a4cdf-c986-4e2d-b324-1f7f2a0f1779.pdf'},
#  {'Code': 'IEWEBWC250_0000_0300',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IEWEBWC250_0000_0300/IEWEBWC250_0000_0300_photo_0_thumbnail.jpg',
#   'WaterQualityId': 3,
#   'WaterQualityName': 'Poor',
#   'Name': 'Dooega Beach, Achill Island',
#   'CountyName': 'Mayo',
#   'StatusTypeId': 1,
#   'StartDate': '2023-07-07T09:41:36',
#   'EndDate': None,
#   'RestrictionTypeId': 2,
#   'RestrictionTypeName': 'Bathing is prohibited',
#   'RestrictionGroupTypeId': 2,
#   'RestrictionGroupTypeName': 'Pollution',
#   'IncidentDescription': 'Water quality deteriorated due to suspected agricultural activities/runoff',
#   'IsShortTermPollution': 1,
#   'WarningNoticeUrl': 'https://www.beaches.ie/wp-content/files//notice/de683661-3320-4d7b-9365-5cde9b9f628b.pdf'},
#  {'Code': 'BPNBF120000060002',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//BPNBF120000060002/BPNBF120000060002_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Clifden Beach',
#   'CountyName': 'Galway',
#   'StatusTypeId': 4,
#   'StartDate': '2023-03-01T12:06:16',
#   'EndDate': '2024-02-29T00:00:00',
#   'RestrictionTypeId': 30,
#   'RestrictionTypeName': 'Do not Swim',
#   'RestrictionGroupTypeId': 2,
#   'RestrictionGroupTypeName': 'Pollution',
#   'IncidentDescription': 'Water Quality deteriorated',
#   'IsShortTermPollution': 0,
#   'WarningNoticeUrl': None},
#  {'Code': 'BPNBF070000020002',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//BPNBF070000020002/BPNBF070000020002_photo_0_thumbnail.jpg',
#   'WaterQualityId': 3,
#   'WaterQualityName': 'Poor',
#   'Name': 'Merrion Strand',
#   'CountyName': 'Dublin',
#   'StatusTypeId': 4,
#   'StartDate': '2023-02-09T00:00:00',
#   'EndDate': '2024-02-09T00:00:00',
#   'RestrictionTypeId': 30,
#   'RestrictionTypeName': 'Do not Swim',
#   'RestrictionGroupTypeId': 2,
#   'RestrictionGroupTypeName': 'Pollution',
#   'IncidentDescription': 'Water Quality deteriorated',
#   'IsShortTermPollution': 0,
#   'WarningNoticeUrl': None},
#  {'Code': 'IEEABWC020_0000_0600',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IEEABWC020_0000_0600/IEEABWC020_0000_0600_photo_1_thumbnail.jpg',
#   'WaterQualityId': 1,
#   'WaterQualityName': 'Good',
#   'Name': 'Balbriggan, Front Strand Beach',
#   'CountyName': 'Dublin',
#   'StatusTypeId': 1,
#   'StartDate': None,
#   'EndDate': None,
#   'RestrictionTypeId': None,
#   'RestrictionTypeName': None,
#   'RestrictionGroupTypeId': None,
#   'RestrictionGroupTypeName': None,
#   'IncidentDescription': None,
#   'IsShortTermPollution': None,
#   'WarningNoticeUrl': None},
#  {'Code': 'IEWEBWC010_0000_0400',
#   'HasRestrictionInPlace': True,
#   'MainPhotoThumbnailUrl': 'https://www.beaches.ie/wp-content/files//gallery//IEWEBWC010_0000_0400/IEWEBWC010_0000_0400_photo_0_thumbnail.jpg',
#   'WaterQualityId': 0,
#   'WaterQualityName': 'Excellent',
#   'Name': 'Trá na mBan, An Spidéal',
#   'CountyName': 'Galway',
#   'StatusTypeId': 1,
#   'StartDate': None,
#   'EndDate': None,
#   'RestrictionTypeId': None,
#   'RestrictionTypeName': None,
#   'RestrictionGroupTypeId': None,
#   'RestrictionGroupTypeName': None,
#   'IncidentDescription': None,
#   'IsShortTermPollution': None,
#   'WarningNoticeUrl': None}]
