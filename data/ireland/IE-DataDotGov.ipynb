# %%
import requests
import pandas as pd
import json
import geopandas
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame

# %%
server = "https://data.epa.ie/bw/api/v1/locations?per_page=500"

# %%
response = requests.get(server)
data = response.json()
data
# Out:
# {'count': 222,
#  'length': 500,
#  'page': 1,
#  'list': [{'location_id': 1,
#    'beach_id': 'IEWEBWL29_194_0100',
#    'beach_name': 'Loughrea Lake',
#    'hashtag': 'loughrealake',
#    'county_name': 'Galway',
#    'local_authority_name': 'Galway County Council',
#    'easting': 162397,
#    'northing': 215167,
#    'beach_type': 'Identified Beach',
#    'beach_description': 'Loughrea Lake Bathing area is pleasantly situated in a shallow relatively sandy area of the lake between a man made pier on the west and a small beach on the eastern end. Surrounding the bathing area is amenity grounds composed of grassy areas, footpaths, planted trees and shrubs and flower beds. The Lake supports a variety of bird species. The lake is a designated Special Protection Area and Natural Heritage Area. Activities include swimming, sailing, windsurfing, angling and canoeing.',
#    'annual_water_quality_assessment': 'Loughrea Lake is classified as achieving Excellent Water Quality in 2021 based on the assessment of bacteriological results for the period 2018 to 2021. Loughrea Lake has achieved an Excellent Water Quality rating for the four consecutive years 2018 to 2021. Annual water quality ratings are generally calculated using monitoring results over a four-year period and are assessed against stringent bacterial limits to protect bather health.',
#    'next_monitoring_date': None,
#    'beach_profile_url': 'https://www.beaches.ie/wp-content/files//profile/BWPR00181_2013_01_profile.pdf',
#    'profile_url_description': 'Profile for Loughrea Lake for 2013',
#    'profile_last_updated_on': 2014,
#    'current_annual_water_quality_classification': None,
#    'current_annual_classification_year': None,
#    'year1_annual_water_quality_classification': 'Excellent Quality',
#    'year1_annual_classification_year': 2021,
#    'year2_annual_water_quality_classification': 'Excellent Quality',
#    'year2_annual_classification_year': 2020,
#    'year3_annual_water_quality_classification': 'Excellent Quality',
#    'year3_annual_classification_year': 2019,
#    'has_all_season_bathing_restriction_in_place': 'No',
#    'reason_for_all_season_bathing_restriction': None,
#    'short_term_pollution_risk': 'Yes',
#    'is_blue_flag': 'Yes',
#    'is_green_coast': 'No',
#    'has_toilets': 'Yes',
#    'toilet_details': None,
#    'is_disability_accessible': 'Yes',
#    'disability_accessible_details': 'Access to waters edge.',
#    'has_beach_wheelchair': 'No',
#    'beach_wheelchair_availability': None,
#    'has_first_aid': 'Yes',
#    'first_aid_availability_details': 'lifeguard huts during lifeguard season',
#    'has_lifebuoy': 'Yes',
#    'lifebuoy_details': None,
#    'has_lifeguard': 'Yes',
#    'lifeguard_availability': '12-6 7 days July & Aug weekend June/Sept',
#    'has_parking': 'Yes',
#    'parking_details': None,
#    'is_public_transport_available': 'No',
#    'public_transport_details': None,
#    'is_natural_sensitive_area': 'Yes',
#    'natural_sensitive_area_details': None,
#    'has_beach_activity_zones': 'No',
#    'beach_activity_zones_details': None,
#    'has_beach_information_board': 'Yes',
#    'beach_information_board_details': None,
#    'are_dogs_allowed_on_lead': 'Yes',
#    'dogs_allowed_on_lead_details': None,
#    'dogs_not_allowed': 'No',
#    'dogs_not_allowed_details': None,
#    'cars_not_allowed_on_beach': 'Yes',
#    'cars_not_allowed_on_beach_details': None,
#    'cars_allowed_on_beach': 'No',
#    'cars_allowed_on_beach_details': None,
#    'has_car_free_zone': 'No',
#    'car_free_zone_details': None,
#    'has_litter_bin': 'Yes',
#    'litter_bin_details': None,
#    'has_recycling_facility': 'Yes',
#    'recycling_facility_details': None,
#    'last_updated': '2022-12-14T07:59:33'},
#   {'location_id': 2,
#    'beach_id': 'IESWBWC090_0000_0300',
#    'beach_name': 'Garrylucas, White Strand',
#    'hashtag': 'garrylucas',
#    'county_name': 'Cork',
#    'local_authority_name': 'Cork County Council',
#    'easting': 160627,
#    'northing': 43157,
#    'beach_type': 'Identified Beach',
#    'beach_description': 'Garrylucas beach is a gently sloping, sandy beach which is flanked on both sides by rocky cliffs. The beach is a south west facing beach and is quite open to rough weather and rough seas. Garrylucas beach has sand dunes to the north and Garrylucas Marsh proposed Natural Heritage Area (pNHA 000087) is located north of the dunes. The beach is used to some extent by anglers, walkers, surfers and windsurfers.',
#    'annual_water_quality_assessment': 'Garrylucas, White Strand is classified as achieving Excellent Water Quality in 2021 based on the assessment of bacteriological results for the period 2018 to 2021. Garrylucas, White Strand has achieved an Excellent Water Quality rating for the four consecutive years 2018 to 2021. Annual water quality ratings are generally calculated using monitoring results over a four-year period and are assessed against stringent bacterial limits to protect bather health.',
#    'next_monitoring_date': None,
#    'beach_profile_url': 'https://www.beaches.ie/wp-content/files//profile/BWPR00632_2022_01_profile.pdf',
#    'profile_url_description': 'Profile for Garrylucas, White Strand for 2022',
#    'profile_last_updated_on': 2022,
#    'current_annual_water_quality_classification': None,
#    'current_annual_classification_year': None,
#    'year1_annual_water_quality_classification': 'Excellent Quality',
#    'year1_annual_classification_year': 2021,
#    'year2_annual_water_quality_classification': 'Excellent Quality',
#    'year2_annual_classification_year': 2020,
#    'year3_annual_water_quality_classification': 'Excellent Quality',
#    'year3_annual_classification_year': 2019,
#    'has_all_season_bathing_restriction_in_place': 'No',
#    'reason_for_all_season_bathing_restriction': None,
#    'short_term_pollution_risk': 'No',
#    'is_blue_flag': 'Yes',
#    'is_green_coast': 'No',
#    'has_toilets': 'Yes',
#    'toilet_details': None,
#    'is_disability_accessible': 'No',
#    'disability_accessible_details': None,
#    'has_beach_wheelchair': 'No',
#    'beach_wheelchair_availability': None,
#    'has_first_aid': 'Yes',
#    'first_aid_availability_details': 'With Lifeguards',
#    'has_lifebuoy': 'No',
#    'lifebuoy_details': None,
#    'has_lifeguard': 'Yes',
#    'lifeguard_availability': None,
#    'has_parking': 'Yes',
#    'parking_details': None,
#    'is_public_transport_available': 'No',
#    'public_transport_details': None,
#    'is_natural_sensitive_area': 'Yes',
#    'natural_sensitive_area_details': None,
#    'has_beach_activity_zones': 'No',
#    'beach_activity_zones_details': None,
#    'has_beach_information_board': 'Yes',
#    'beach_information_board_details': None,
#    'are_dogs_allowed_on_lead': 'No',
#    'dogs_allowed_on_lead_details': None,
#    'dogs_not_allowed': 'Yes',
#    'dogs_not_allowed_details': 'Dogs are not allowed on this beach between 10.30 a.m. & 7.00 p.m. during the bathing season which runs from 1st June to 15th September.',
#    'cars_not_allowed_on_beach': 'Yes',
#    'cars_not_allowed_on_beach_details': None,
#    'cars_allowed_on_beach': 'No',
#    'cars_allowed_on_beach_details': None,
#    'has_car_free_zone': 'No',
#    'car_free_zone_details': None,
#    'has_litter_bin': 'Yes',
#    'litter_bin_details': None,
#    'has_recycling_facility': 'Yes',
#    'recycling_facility_details': None,
#    'last_updated': '2023-02-10T09:28:39'},
#   {'location_id': 3,
#    'beach_id': 'IESWBWC040_0000_0100',
#    'beach_name': 'Garryvoe',
#    'hashtag': 'garryvoe',
#    'county_name': 'Cork',
#    'local_authority_name': 'Cork County Council',
#    'easting': 199890,
#    'northing': 67220,
#    'beach_type': 'Identified Beach',
#    'beach_description': 'Garryvoe beach is a south east facing, gently sloping, sandy/pebble beach located on a long stretch of sandy coastline. It is quite open to rough weather and rough seas. There is an area of sand dunes to the rear (west). The bathing water is located within Ballycotton, Ballynamona and Shanagarry proposed Natural Heritage Area (pNHA 000076) and is also located within Ballycotton Bay Special Protection Area (SPA 004022). The beach is used to some extent by anglers, walkers, surfers and windsurfers.',
#    'annual_water_quality_assessment': 'Garryvoe is classified as achieving Sufficient Water Quality in 2021 based on the assessment of bacteriological results for the period 2018 to 2021. Garryvoe had achieved a Sufficient Water Quality rating for the four consecutive years 2018 to 2021. Annual water quality ratings are generally calculated using monitoring results over a four-year period and are assessed against stringent bacterial limits to protect bather health.',
#    'next_monitoring_date': None,
#    'beach_profile_url': 'https://www.beaches.ie/wp-content/files//profile/BWPR00657_2022_01_profile.pdf',
#    'profile_url_description': 'Profile for Garryvoe for 2022',
#    'profile_last_updated_on': 2022,
#    'current_annual_water_quality_classification': None,
#    'current_annual_classification_year': None,
#    'year1_annual_water_quality_classification': 'Sufficient Quality',
#    'year1_annual_classification_year': 2021,
#    'year2_annual_water_quality_classification': 'Sufficient Quality',
#    'year2_annual_classification_year': 2020,
#    'year3_annual_water_quality_classification': 'Sufficient Quality',
#    'year3_annual_classification_year': 2019,
#    'has_all_season_bathing_restriction_in_place': 'No',
#    'reason_for_all_season_bathing_restriction': None,
#    'short_term_pollution_risk': 'Yes',
#    'is_blue_flag': 'No',
#    'is_green_coast': 'No',
#    'has_toilets': 'Yes',
#    'toilet_details': None,
#    'is_disability_accessible': 'Yes',
#    'disability_accessible_details': 'Wheelchair Ramp',
#    'has_beach_wheelchair': 'No',
#    'beach_wheelchair_availability': None,
#    'has_first_aid': 'Yes',
#    'first_aid_availability_details': 'With Lifeguards',
#    'has_lifebuoy': 'Yes',
#    'lifebuoy_details': None,
#    'has_lifeguard': 'Yes',
#    'lifeguard_availability': None,
#    'has_parking': 'Yes',
#    'parking_details': None,
#    'is_public_transport_available': 'No',
#    'public_transport_details': None,
#    'is_natural_sensitive_area': 'Yes',
#    'natural_sensitive_area_details': None,
#    'has_beach_activity_zones': 'No',
#    'beach_activity_zones_details': None,
#    'has_beach_information_board': 'Yes',
#    'beach_information_board_details': None,
#    'are_dogs_allowed_on_lead': 'Yes',
#    'dogs_allowed_on_lead_details': None,
#    'dogs_not_allowed': 'No',
#    'dogs_not_allowed_details': None,
#    'cars_not_allowed_on_beach': 'Yes',
#    'cars_not_allowed_on_beach_details': None,
#    'cars_allowed_on_beach': 'No',
#    'cars_allowed_on_beach_details': None,
#    'has_car_free_zone': 'No',
#    'car_free_zone_details': None,
#    'has_litter_bin': 'Yes',
#    'litter_bin_details': None,
#    'has_recycling_facility': 'Yes',
#    'recycling_facility_details': None,
#    'last_updated': '2023-02-10T09:28:48'},
#   {'location_id': 4,
#    'beach_id': 'IESEBWC010_0000_0500',
#    'beach_name': 'Ballymoney, North Beach',
#    'hashtag': 'ballymoney',
#    'county_name': 'Wexford',
#    'local_authority_name': 'Wexford County Council',
#    'easting': 321720,
#    'northing': 160261,
#    'beach_type': 'Identified Beach',
#    'beach_description': 'Ballymoney North beach is a rural peaceful beach with a relatively gentle slope. The sand type is medium hardness. Deposition offshore into a series of sand-banks offers protection to the beach. The sand dunes extend between 50m and 100m to the rear (west) of the beach. Ballymoney beach is part of a Natural Heritage Area (NHA). Ballymoney beaches are also a popular fishing spot. The bathing area is approximately 300m long and approximately 0.06 km&sup2; in area.',
#    'annual_water_quality_assessment': 'Ballymoney, North Beach is classified as achieving Excellent Water Quality in 2021 based on the assessment of bacteriological results for the period 2018 to 2021. Ballymoney, North Beach achieved a Good Water Quality rating in 2020, and an Excellent Water Quality rating in 2019 and 2018. Annual water quality ratings are generally calculated using monitoring results over a four-year period and are assessed against stringent bacterial limits to protect bather health.',
#    'next_monitoring_date': None,
#    'beach_profile_url': 'https://www.beaches.ie/wp-content/files//profile/BWPR00591_2021_01_profile.pdf',
#    'profile_url_description': 'Profile for Ballymoney, North Beach for 2021',
#    'profile_last_updated_on': 2022,
#    'current_annual_water_quality_classification': None,
#    'current_annual_classification_year': None,
#    'year1_annual_water_quality_classification': 'Excellent Quality',
#    'year1_annual_classification_year': 2021,
#    'year2_annual_water_quality_classification': 'Good Quality',
#    'year2_annual_classification_year': 2020,
#    'year3_annual_water_quality_classification': 'Excellent Quality',
#    'year3_annual_classification_year': 2019,
#    'has_all_season_bathing_restriction_in_place': 'No',
#    'reason_for_all_season_bathing_restriction': None,
#    'short_term_pollution_risk': 'Yes',
#    'is_blue_flag': 'Yes',
#    'is_green_coast': 'No',
#    'has_toilets': 'Yes',
#    'toilet_details': None,
#    'is_disability_accessible': 'No',
#    'disability_accessible_details': None,
#    'has_beach_wheelchair': 'No',
#    'beach_wheelchair_availability': None,
#    'has_first_aid': 'Yes',
#    'first_aid_availability_details': 'Available from Lifeguard hut',
#    'has_lifebuoy': 'Yes',
#    'lifebuoy_details': None,
#    'has_lifeguard': 'Yes',
#    'lifeguard_availability': None,
#    'has_parking': 'Yes',
#    'parking_details': None,
#    'is_public_transport_available': 'No',
#    'public_transport_details': None,
#    'is_natural_sensitive_area': 'Yes',
#    'natural_sensitive_area_details': None,
#    'has_beach_activity_zones': 'No',
#    'beach_activity_zones_details': None,
#    'has_beach_information_board': 'Yes',
#    'beach_information_board_details': None,
#    'are_dogs_allowed_on_lead': 'Yes',
#    'dogs_allowed_on_lead_details': None,
#    'dogs_not_allowed': 'No',
#    'dogs_not_allowed_details': None,
#    'cars_not_allowed_on_beach': 'Yes',
#    'cars_not_allowed_on_beach_details': None,
#    'cars_allowed_on_beach': 'No',
#    'cars_allowed_on_beach_details': None,
#    'has_car_free_zone': 'No',
#    'car_free_zone_details': None,
#    'has_litter_bin': 'Yes',
#    'litter_bin_details': None,
#    'has_recycling_facility': 'Yes',
#    'recycling_facility_details': None,
#    'last_updated': '2022-12-14T07:59:13'},
#   {'location_id': 5,
#    'beach_id': 'IESEBWC010_0000_0300',
#    'beach_name': 'Morriscastle',
#    'hashtag': 'morriscastle',
#    'county_name': 'Wexford',
#    'local_authority_name': 'Wexford County Council',
#    'easting': 319664,
#    'northing': 141674,
#    'beach_type': 'Identified Beach',
#    'beach_description': 'Morriscastle beach is a rural peaceful fine-sand beach with a relatively gentle slope. The sand type is soft and wind blown. The sand dunes extend approximately 100m to the rear (west) of the beach. There is no significant vegetation growing in the waters off the beach. The Kilmuckridge-Tinaberna sand hills support dune habitat types, which make them a Special Area of Conservation. As Morriscastle beach falls within this area, it is an SAC. The bathing area is approximately 1.0 km long and 0.2 km&sup2; in area.',
#    'annual_water_quality_assessment': 'Morriscastle is classified as achieving Excellent Water Quality in 2021 based on the assessment of bacteriological results for the period 2018 to 2021. Morriscastle has achieved an Excellent Water Quality rating for the four consecutive years 2018 to 2021. Annual water quality ratings are generally calculated using monitoring results over a four-year period and are assessed against stringent bacterial limits to protect bather health.',
#    'next_monitoring_date': None,
#    'beach_profile_url': 'https://www.beaches.ie/wp-content/files//profile/BWPR00597_2021_01_profile.pdf',
#    'profile_url_description': 'Profile for Morriscastle for 2021',
#    'profile_last_updated_on': 2022,
#    'current_annual_water_quality_classification': None,
#    'current_annual_classification_year': None,
#    'year1_annual_water_quality_classification': 'Excellent Quality',
#    'year1_annual_classification_year': 2021,
#    'year2_annual_water_quality_classification': 'Excellent Quality',
#    'year2_annual_classification_year': 2020,
#    'year3_annual_water_quality_classification': 'Excellent Quality',
#    'year3_annual_classification_year': 2019,
#    'has_all_season_bathing_restriction_in_place': 'No',
#    'reason_for_all_season_bathing_restriction': None,
#    'short_term_pollution_risk': 'Yes',
#    'is_blue_flag': 'Yes',
#    'is_green_coast': 'No',
#    'has_toilets': 'Yes',
#    'toilet_details': None,
#    'is_disability_accessible': 'Yes',
#    'disability_accessible_details': 'Wooden boardwalk',
#    'has_beach_wheelchair': 'Yes',
#    'beach_wheelchair_availability': "Contact Lawler's Shop 053-9130334 June to Aug inclusive.",
#    'has_first_aid': 'Yes',
#    'first_aid_availability_details': 'Available from Lifeguard hut',
#    'has_lifebuoy': 'Yes',
#    'lifebuoy_details': None,
#    'has_lifeguard': 'Yes',
#    'lifeguard_availability': None,
#    'has_parking': 'Yes',
#    'parking_details': None,
#    'is_public_transport_available': 'No',
#    'public_transport_details': None,
#    'is_natural_sensitive_area': 'Yes',
#    'natural_sensitive_area_details': None,
#    'has_beach_activity_zones': 'No',
#    'beach_activity_zones_details': None,
#    'has_beach_information_board': 'Yes',
#    'beach_information_board_details': None,
#    'are_dogs_allowed_on_lead': 'Yes',
#    'dogs_allowed_on_lead_details': None,
#    'dogs_not_allowed': 'No',
#    'dogs_not_allowed_details': None,
#    'cars_not_allowed_on_beach': 'Yes',
#    'cars_not_allowed_on_beach_details': None,
#    'cars_allowed_on_beach': 'No',
#    'cars_allowed_on_beach_details': None,
#    'has_car_free_zone': 'No',
#    'car_free_zone_details': None,
#    'has_litter_bin': 'Yes',
#    'litter_bin_details': None,
#    'has_recycling_facility': 'Yes',
#    'recycling_facility_details': None,
#    'last_updated': '2022-12-14T07:59:13'},
#   {'location_id': 6,
#    'beach_id': 'IENBBWC025_0000_0300',
#    'beach_name': 'Port, Lurganboy',
#    'hashtag': 'portlurganboy',
#    'county_name': 'Louth',
#    'local_authority_name': 'Louth County Council',
#    'easting': 314791,
#    'northing': 287787,
#    'beach_type': 'Identified Beach',
#    'beach_description': 'The beach is mainly sandy with a small area of rocks consisting of sand dunes. There are mature sand dunes located on the beach which support a variety of plant species. There is also a variety of wildlife including crabs and seaweed. The nearest sites which have a statutory designation for conservation are Clogherhead SAC and Dunany Point NHA. The length of the bathing area is approximately 2300m in length. The beach is gently sloping into the sea at the bathing area.',
#    'annual_water_quality_assessment': 'Port, Lurganboy is classified as achieving Excellent Water Quality in 2021 based on the assessment of bacteriological results for the period 2018 to 2021. Port, Lurganboy has achieved an Excellent Water Quality rating for the four consecutive years 2018 to 2021. Annual water quality ratings are generally calculated using monitoring results over a four-year period and are assessed against stringent bacterial limits to protect bather health.',
#    'next_monitoring_date': None,
#    'beach_profile_url': 'https://www.beaches.ie/wp-content/files/profile/BWPR00193_2013_01_profile.pdf',
#    'profile_url_description': 'Profile for Port, Lurganboy for 2013',
#    'profile_last_updated_on': 2014,
#    'current_annual_water_quality_classification': None,
#    'current_annual_classification_year': None,
#    'year1_annual_water_quality_classification': 'Excellent Quality',
#    'year1_annual_classification_year': 2021,
#    'year2_annual_water_quality_classification': 'Excellent Quality',
#    'year2_annual_classification_year': 2020,
#    'year3_annual_water_quality_classification': 'Excellent Quality',
#    'year3_annual_classification_year': 2019,
#    'has_all_season_bathing_restriction_in_place': 'No',
#    'reason_for_all_season_bathing_restriction': None,
#    'short_term_pollution_risk': 'Yes',
#    'is_blue_flag': 'Yes',
#    'is_green_coast': 'No',
#    'has_toilets': 'Yes',
#    'toilet_details': None,
#    'is_disability_accessible': 'No',
#    'disability_accessible_details': None,
#    'has_beach_wheelchair': 'No',
#    'beach_wheelchair_availability': None,
#    'has_first_aid': 'Yes',
#    'first_aid_availability_details': None,
#    'has_lifebuoy': 'Yes',
#    'lifebuoy_details': None,
#    'has_lifeguard': 'Yes',
#    'lifeguard_availability': None,
#    'has_parking': 'Yes',
#    'parking_details': None,
#    'is_public_transport_available': 'No',
#    'public_transport_details': None,
#    'is_natural_sensitive_area': 'Yes',
#    'natural_sensitive_area_details': None,
#    'has_beach_activity_zones': 'Yes',
#    'beach_activity_zones_details': 'Details on Information Board',
#    'has_beach_information_board': 'Yes',
#    'beach_information_board_details': None,
#    'are_dogs_allowed_on_lead': 'Yes',
#    'dogs_allowed_on_lead_details': None,
#    'dogs_not_allowed': 'No',
#    'dogs_not_allowed_details': None,
#    'cars_not_allowed_on_beach': 'Yes',
#    'cars_not_allowed_on_beach_details': None,
#    'cars_allowed_on_beach': 'No',
#    'cars_allowed_on_beach_details': None,
#    'has_car_free_zone': 'No',
#    'car_free_zone_details': None,
#    'has_litter_bin': 'Yes',
#    'litter_bin_details': None,
#    'has_recycling_facility': 'Yes',
#    'recycling_facility_details': None,
#    'last_updated': '2022-12-14T07:59:07'},
#   {'location_id': 7,
#    'beach_id': 'IEEABWC140_0000_0300',
#    'beach_name': 'Brittas Bay North',
#    'hashtag': 'brittasbaynorth',
#    'county_name': 'Wicklow',
#    'local_authority_name': 'Wicklow County Council',
#    'easting': 330865,
#    'northing': 182983,
#    'beach_type': 'Identified Beach',
#    'beach_description': 'Brittas Bay North Beach is a long, gently sloping, sandy beach. It has hilly sand dunes which support two protected plant species. The beach gradually falls away with sand bars common. Water sport activities available include surfing, windsurfing canoeing and snorkelling.',
#    'annual_water_quality_assessment': 'Brittas Bay North is classified as achieving Excellent Water Quality in 2021 based on the assessment of bacteriological results for the period 2018 to 2021. Brittas Bay North has achieved an Excellent Water Quality rating for the four consecutive years 2018 to 2021. Annual water quality ratings are generally calculated using monitoring results over a four-year period and are assessed against stringent bacterial limits to protect bather health.',
#    'next_monitoring_date': None,
#    'beach_profile_url': 'https://www.beaches.ie/wp-content/files//profile/BWPR00514_2019_01_profile.pdf',
#    'profile_url_description': 'Profile for Brittas Bay North for 2019',
#    'profile_last_updated_on': 2019,
#    'current_annual_water_quality_classification': None,
#    'current_annual_classification_year': None,
#    'year1_annual_water_quality_classification': 'Excellent Quality',
#    'year1_annual_classification_year': 2021,
#    'year2_annual_water_quality_classification': 'Excellent Quality',
#    'year2_annual_classification_year': 2020,
#    'year3_annual_water_quality_classification': 'Excellent Quality',
#    'year3_annual_classification_year': 2019,
#    'has_all_season_bathing_restriction_in_place': 'No',
#    'reason_for_all_season_bathing_restriction': None,
#    'short_term_pollution_risk': 'Yes',
#    'is_blue_flag': 'Yes',
#    'is_green_coast': 'No',
#    'has_toilets': 'Yes',
#    'toilet_details': None,
#    'is_disability_accessible': 'No',
#    'disability_accessible_details': None,
#    'has_beach_wheelchair': 'Yes',
#    'beach_wheelchair_availability': 'The Beach Wheelchair is available at Brittas Bay North Beach 7 days a week from 11am – 7pm during the bathing season in June, July & August and over the first 2 weekends of September. Special requests can be made outside of this period.The use of the wheelchair is FREE but it must be reserved in advance using the booking system at https://www.wicklow.ie/Living/Beachwheelchair.',
#    'has_first_aid': 'Yes',
#    'first_aid_availability_details': 'Available at Lifeguard station',
#    'has_lifebuoy': 'Yes',
#    'lifebuoy_details': None,
#    'has_lifeguard': 'Yes',
#    'lifeguard_availability': None,
#    'has_parking': 'Yes',
#    'parking_details': None,
#    'is_public_transport_available': 'No',
#    'public_transport_details': None,
#    'is_natural_sensitive_area': 'Yes',
#    'natural_sensitive_area_details': None,
#    'has_beach_activity_zones': 'Yes',
#    'beach_activity_zones_details': 'Separate Area for Water Sport Activities',
#    'has_beach_information_board': 'Yes',
#    'beach_information_board_details': None,
#    'are_dogs_allowed_on_lead': 'No',
#    'dogs_allowed_on_lead_details': None,
#    'dogs_not_allowed': 'Yes',
#    'dogs_not_allowed_details': 'Not allowed within lifeguard patrol zone/bathing area below high tide mark.',
#    'cars_not_allowed_on_beach': 'Yes',
#    'cars_not_allowed_on_beach_details': None,
#    'cars_allowed_on_beach': 'No',
#    'cars_allowed_on_beach_details': None,
#    'has_car_free_zone': 'No',
#    'car_free_zone_details': None,
#    'has_litter_bin': 'Yes',
#    'litter_bin_details': None,
#    'has_recycling_facility': 'Yes',
#    'recycling_facility_details': None,
#    'last_updated': '2022-12-14T07:59:06'},
#   {'location_id': 8,
#    'beach_id': 'IEEABWL07_274_0100',
#    'beach_name': 'The Cut, Lough Lene',
#    'hashtag': 'thecutloughlene',
#    'county_name': 'Westmeath',
#    'local_authority_name': 'Westmeath County Council',
#    'easting': 253215,
#    'northing': 268022,
#    'beach_type': 'Identified Beach',
#    'beach_description': 'The Cut is an inland bathing area located on the Shores of Lough Lene. Lough Lene supports a diverse aquatic flora; such as pond weed and stoneworts. The bathing area is a popular bathing area. Jet ski bye laws in place prohibit use of jet skis on the lake. The bathing area extends over an area of approximately 70 meters by 170 meters wide.',
#    'annual_water_quality_assessment': 'The Cut, Lough Lene is classified as achieving Excellent Water Quality in 2021 based on the assessment of bacteriological results for the period 2018 to 2021. The Cut, Lough Lene has achieved an Excellent Water Quality rating for the four consecutive years 2018 to 2021. Annual water quality ratings are generally calculated using monitoring results over a four-year period and are assessed against stringent bacterial limits to protect bather health.',
#    'next_monitoring_date': None,
#    'beach_profile_url': 'https://www.beaches.ie/wp-content/files/profile/BWPR00285_2014_01_profile.pdf',
#    'profile_url_description': 'Profile for The Cut, Lough Lene for 2014',
#    'profile_last_updated_on': 2014,
#    'current_annual_water_quality_classification': 'Excellent Quality',
#    'current_annual_classification_year': 2021,
#    'year1_annual_water_quality_classification': 'Excellent Quality',
#    'year1_annual_classification_year': 2020,
#    'year2_annual_water_quality_classification': 'Excellent Quality',
#    'year2_annual_classification_year': 2019,
#    'year3_annual_water_quality_classification': 'Excellent Quality',
#    'year3_annual_classification_year': 2018,
#    'has_all_season_bathing_restriction_in_place': 'No',
#    'reason_for_all_season_bathing_restriction': None,
#    'short_term_pollution_risk': 'No',
#    'is_blue_flag': 'No',
#    'is_green_coast': 'No',
#    'has_toilets': 'Yes',
#    'toilet_details': None,
#    'is_disability_accessible': 'Yes',
#    'disability_accessible_details': 'Access to lake shoreline',
#    'has_beach_wheelchair': 'No',
#    'beach_wheelchair_availability': None,
#    'has_first_aid': 'No',
#    'first_aid_availability_details': None,
#    'has_lifebuoy': 'No',
#    'lifebuoy_details': None,
#    'has_lifeguard': 'No',
#    'lifeguard_availability': None,
#    'has_parking': 'Yes',
#    'parking_details': None,
#    'is_public_transport_available': 'No',
#    'public_transport_details': None,
#    'is_natural_sensitive_area': 'Yes',
#    'natural_sensitive_area_details': None,
#    'has_beach_activity_zones': 'No',
#    'beach_activity_zones_details': None,
#    'has_beach_information_board': 'Yes',
#    'beach_information_board_details': None,
#    'are_dogs_allowed_on_lead': 'No',
#    'dogs_allowed_on_lead_details': None,
#    'dogs_not_allowed': 'Yes',
#    'dogs_not_allowed_details': None,
#    'cars_not_allowed_on_beach': 'Yes',
#    'cars_not_allowed_on_beach_details': None,
#    'cars_allowed_on_beach': 'No',
#    'cars_allowed_on_beach_details': None,
#    'has_car_free_zone': 'No',
#    'car_free_zone_details': None,
#    'has_litter_bin': 'Yes',
#    'litter_bin_details': None,
#    'has_recycling_facility': 'Yes',
#    'recycling_facility_details': None,
#    'last_updated': '2022-12-14T07:59:07'},
#   {'location_id': 9,
#    'beach_id': 'IESHBWL27_72_0100',
#    'beach_name': 'Ballyallia Lake, Ennis',
#    'hashtag': 'ballyallialake',
#    'county_name': 'Clare',
#    'local_authority_name': 'Clare County Council',
#    'easting': 134654,
#    'northing': 180870,
#    'beach_type': 'Identified Beach',
#    'beach_description': 'The bathing area at Ballyallia Lake is based around a small slipway, consists of small stones and extends 70m along the shoreline. Ballyallia Lake is a Special Area of Conservation as well as a Special Protection Area for birds and wildlife sanctuary. Activities include walking and fishing. It is a popular place for young families to feed the ducks and have picnics. Beach bye-laws are in place with horse riding and dogs prohibited between 11am and 6pm during the summer season.',
#    'annual_water_quality_assessment': 'Ballyallia Lake, Ennis is classified as achieving Excellent Water Quality in 2021 based on the assessment of bacteriological results for the period 2018 to 2021. Ballyallia Lake, Ennis has achieved an Excellent Water Quality rating for the four consecutive years 2018 to 2021. Annual water quality ratings are generally calculated using monitoring results over a four-year period and are assessed against stringent bacterial limits to protect bather health.',
#    'next_monitoring_date': None,
#    'beach_profile_url': 'https://www.beaches.ie/wp-content/files//profile/BWPR00618_2022_01_profile.pdf',
#    'profile_url_description': 'Profile for Ballyallia Lake, Ennis for 2022',
#    'profile_last_updated_on': 2022,
#    'current_annual_water_quality_classification': None,
#    'current_annual_classification_year': None,
#    'year1_annual_water_quality_classification': 'Excellent Quality',
#    'year1_annual_classification_year': 2021,
#    'year2_annual_water_quality_classification': 'Excellent Quality',
#    'year2_annual_classification_year': 2020,
#    'year3_annual_water_quality_classification': 'Excellent Quality',
#    'year3_annual_classification_year': 2019,
#    'has_all_season_bathing_restriction_in_place': 'No',
#    'reason_for_all_season_bathing_restriction': None,
#    'short_term_pollution_risk': 'Yes',
#    'is_blue_flag': 'No',
#    'is_green_coast': 'Yes',
#    'has_toilets': 'No',
#    'toilet_details': None,
#    'is_disability_accessible': 'Yes',
#    'disability_accessible_details': 'Gentle sloping ramp to pier',
#    'has_beach_wheelchair': 'No',
#    'beach_wheelchair_availability': None,
#    'has_first_aid': 'No',
#    'first_aid_availability_details': None,
#    'has_lifebuoy': 'Yes',
#    'lifebuoy_details': None,
#    'has_lifeguard': 'No',
#    'lifeguard_availability': None,
#    'has_parking': 'Yes',
#    'parking_details': None,
#    'is_public_transport_available': 'No',
#    'public_transport_details': None,
#    'is_natural_sensitive_area': 'Yes',
#    'natural_sensitive_area_details': None,
#    'has_beach_activity_zones': 'No',
#    'beach_activity_zones_details': None,
#    'has_beach_information_board': 'Yes',
#    'beach_information_board_details': None,
#    'are_dogs_allowed_on_lead': 'Yes',
#    'dogs_allowed_on_lead_details': 'Before 11 am and after 6 pm during summer season, otherwise not allowed at all times onto beach during the summer.',
#    'dogs_not_allowed': 'No',
#    'dogs_not_allowed_details': None,
#    'cars_not_allowed_on_beach': 'Yes',
#    'cars_not_allowed_on_beach_details': None,
#    'cars_allowed_on_beach': 'No',
#    'cars_allowed_on_beach_details': None,
#    'has_car_free_zone': 'No',
#    'car_free_zone_details': None,
#    'has_litter_bin': 'Yes',
#    'litter_bin_details': None,
#    'has_recycling_facility': 'No',
#    'recycling_facility_details': None,
#    'last_updated': '2022-12-14T07:59:20'},
#   {'location_id': 10,
#    'beach_id': 'IESHBWL25_191a_0300',
#    'beach_name': 'Ballycuggeran',
#    'hashtag': 'ballycuggeran',
#    'county_name': 'Clare',
#    'local_authority_name': 'Clare County Council',
#    'easting': 168753,
#    'northing': 176378,
#    'beach_type': 'Identified Beach',
#    'beach_description': 'Ballycuggeran bathing area is sandy and extends approximately 80m along the shoreline of Lough Derg Special Protection Area. The shoreline in the vicinity of the bathing area is fringed with swamp vegetation. Lough Derg supports a vast variety of birds and fish species. Lough Derg is a popular lake for swimming, sailing and wind surfing. It is also popular for fishing. Beach bye-laws are in place with horse riding and dogs prohibited between 11am and 6pm during the summer season.',
#    'annual_water_quality_assessment': 'Ballycuggeran is classified as achieving Excellent Water Quality in 2021 based on the assessment of bacteriological results for the period 2018 to 2021. Ballycuggeran has achieved an Excellent Water Quality rating for the four consecutive years 2018 to 2021. Annual water quality ratings are generally calculated using monitoring results over a four-year period and are assessed against stringent bacterial limits to protect bather health.',
#    'next_monitoring_date': None,
#    'beach_profile_url': 'https://www.beaches.ie/wp-content/files//profile/BWPR00619_2022_01_profile.pdf',
#    'profile_url_description': 'Profile for Ballycuggeran for 2022',
#    'profile_last_updated_on': 2022,
#    'current_annual_water_quality_classification': None,
#    'current_annual_classification_year': None,
#    'year1_annual_water_quality_classification': 'Excellent Quality',
#    'year1_annual_classification_year': 2021,
#    'year2_annual_water_quality_classification': 'Excellent Quality',
#    'year2_annual_classification_year': 2020,
#    'year3_annual_water_quality_classification': 'Excellent Quality',
#    'year3_annual_classification_year': 2019,
#    'has_all_season_bathing_restriction_in_place': 'No',
#    'reason_for_all_season_bathing_restriction': None,
#    'short_term_pollution_risk': 'Yes',
#    'is_blue_flag': 'Yes',
#    'is_green_coast': 'No',
#    'has_toilets': 'Yes',
#    'toilet_details': None,
#    'is_disability_accessible': 'Yes',
#    'disability_accessible_details': 'Gentle sloping ramp to pier',
#    'has_beach_wheelchair': 'No',
#    'beach_wheelchair_availability': None,
#    'has_first_aid': 'Yes',
#    'first_aid_availability_details': 'Available at Lifeguard hut',
#    'has_lifebuoy': 'Yes',
#    'lifebuoy_details': None,
#    'has_lifeguard': 'Yes',
#    'lifeguard_availability': None,
#    'has_parking': 'Yes',
#    'parking_details': None,
#    'is_public_transport_available': 'No',
#    'public_transport_details': None,
#    'is_natural_sensitive_area': 'Yes',
#    'natural_sensitive_area_details': None,
#    'has_beach_activity_zones': 'No',
#    'beach_activity_zones_details': None,
#    'has_beach_information_board': 'Yes',
#    'beach_information_board_details': None,
#    'are_dogs_allowed_on_lead': 'Yes',
#    'dogs_allowed_on_lead_details': 'Before 11 am and after 6 pm during summer season, otherwise not allowed at all times onto beach during the summer.',
#    'dogs_not_allowed': 'No',
#    'dogs_not_allowed_details': None,
#    'cars_not_allowed_on_beach': 'Yes',
#    'cars_not_allowed_on_beach_details': None,
#    'cars_allowed_on_beach': 'No',
#    'cars_allowed_on_beach_details': None,
#    'has_car_free_zone': 'No',
#    'car_free_zone_details': None,
#    'has_litter_bin': 'Yes',
#    'litter_bin_details': None,
#    'has_recycling_facility': 'Yes',
#    'recycling_facility_details': None,
#    'last_updated': '2022-12-14T07:59:19'},
#   {'location_id': 11,
#    'beach_id': 'IESHBWL25_191a_0100',
#    'beach_name': 'Bathing Place at Portumna',
#    'hashtag': 'portumna',
#    'county_name': 'Galway',
#    'local_authority_name': 'Galway County Council',
#    'easting': 185949,
#    'northing': 203493,
#    'beach_type': 'Identified Beach',
#    'beach_description': 'Portumna bathing water is a pleasant well maintained facility used throughout the year. It is situated in a shallow area of Lough Derg near the town of Portumna. This is an important lake in Ireland for waterfowl. Lough Derg is an area of conservation because of its numbers of fish and freshwater invertebrates. Activities around the bathing area and lake include sailing, windsurfing, canoeing, angling and horse riding.',
#    'annual_water_quality_assessment': 'Bathing Place at Portumna is classified as achieving Excellent Water Quality in 2021 based on the assessment of bacteriological results for the period 2018 to 2021. Bathing Place at Portumna has achieved an Excellent Water Quality rating for the four consecutive years 2018 to 2021. Annual water quality ratings are generally calculated using monitoring results over a four-year period and are assessed against stringent bacterial limits to protect bather health.',
#    'next_monitoring_date': None,
#    'beach_profile_url': 'https://www.beaches.ie/wp-content/files/profile/BWPR00159_2013_01_profile.pdf',
#    'profile_url_description': 'Profile for Bathing Place at Portumna for 2013',
#    'profile_last_updated_on': 2014,
#    'current_annual_water_quality_classification': None,
#    'current_annual_classification_year': None,
#    'year1_annual_water_quality_classification': 'Excellent Quality',
#    'year1_annual_classification_year': 2021,
#    'year2_annual_water_quality_classification': 'Excellent Quality',
#    'year2_annual_classification_year': 2020,
#    'year3_annual_water_quality_classification': 'Excellent Quality',
#    'year3_annual_classification_year': 2019,
#    'has_all_season_bathing_restriction_in_place': 'No',
#    'reason_for_all_season_bathing_restriction': None,
#    'short_term_pollution_risk': 'Yes',
#    'is_blue_flag': 'Yes',
#    'is_green_coast': 'No',
#    'has_toilets': 'Yes',
#    'toilet_details': None,
#    'is_disability_accessible': 'Yes',
#    'disability_accessible_details': 'Access to waters edge.',
#    'has_beach_wheelchair': 'No',
#    'beach_wheelchair_availability': None,
#    'has_first_aid': 'Yes',
#    'first_aid_availability_details': 'lifeguard huts during lifeguard season',
#    'has_lifebuoy': 'Yes',
#    'lifebuoy_details': None,
#    'has_lifeguard': 'Yes',
#    'lifeguard_availability': '12-6 weekends July Aug',
#    'has_parking': 'Yes',
#    'parking_details': None,
#    'is_public_transport_available': 'No',
#    'public_transport_details': None,
#    'is_natural_sensitive_area': 'Yes',
#    'natural_sensitive_area_details': None,
#    'has_beach_activity_zones': 'No',
#    'beach_activity_zones_details': None,
#    'has_beach_information_board': 'Yes',
#    'beach_information_board_details': None,
#    'are_dogs_allowed_on_lead': 'Yes',
#    'dogs_allowed_on_lead_details': None,
#    'dogs_not_allowed': 'No',
#    'dogs_not_allowed_details': None,
#    'cars_not_allowed_on_beach': 'Yes',
#    'cars_not_allowed_on_beach_details': None,
#    'cars_allowed_on_beach': 'No',
#    'cars_allowed_on_beach_details': None,
#    'has_car_free_zone': 'No',
#    'car_free_zone_details': None,
#    'has_litter_bin': 'Yes',
#    'litter_bin_details': None,
#    'has_recycling_facility': 'Yes',
#    'recycling_facility_details': None,
#    'last_updated': '2022-12-14T07:59:19'},
#   {'location_id': 12,
#    'beach_id': 'IESHBWL26_624_0100',
#    'beach_name': 'Keeldra Lough',
#    'hashtag': 'keeldralough',
#    'county_name': 'Leitrim',
#    'local_authority_name': 'Leitrim County Council',
#    'easting': 214971,
#    'northing': 296640,
#    'beach_type': 'Identified Beach',
#    'beach_description': 'Keeldra Lake could be classified as muddy, with a semi-natural riparian zone. This bathing area is approximately 2,000 m2 and the principal swimming zone is expected on the shore side of this man-made pier.',
#    'annual_water_quality_assessment': 'Keeldra Lough is classified as achieving Excellent Water Quality in 2021 based on the assessment of bacteriological results for the period 2018 to 2021. Keeldra Lough has achieved an Excellent Water Quality rating for the four consecutive years 2018 to 2021. Annual water quality ratings are generally calculated using monitoring results over a four-year period and are assessed against stringent bacterial limits to protect bather health.',
#    'next_monitoring_date': None,
#    'beach_profile_url': 'https://www.beaches.ie/wp-content/files//profile/BWPR00533_2020_01_profile.pdf',
#    'profile_url_description': 'Profile for Keeldra Lough for 2020',
#    'profile_last_updated_on': 2021,
#    'current_annual_water_quality_classification': None,
#    'current_annual_classification_year': None,
#    'year1_annual_water_quality_classification': 'Excellent Quality',
#    'year1_annual_classification_year': 2021,
#    'year2_annual_water_quality_classification': 'Excellent Quality',
#    'year2_annual_classification_year': 2020,
#    'year3_annual_water_quality_classification': 'Excellent Quality',
#    'year3_annual_classification_year': 2019,
#    'has_all_season_bathing_restriction_in_place': 'No',
#    'reason_for_all_season_bathing_restriction': None,
#    'short_term_pollution_risk': 'Yes',
#    'is_blue_flag': 'No',
#    'is_green_coast': 'No',
#    'has_toilets': 'Yes',
#    'toilet_details': None,
#    'is_disability_accessible': 'Yes',
#    'disability_accessible_details': 'There is a gentle sloping concrete slipway for users to access to the lake shore. There are no disability accessible points to the lake for bathing. There are a number of steps to navigate to gain entry to the bathing water. A hand rail is in place for support when using the steps for access.',
#    'has_beach_wheelchair': 'No',
#    'beach_wheelchair_availability': None,
#    'has_first_aid': 'No',
#    'first_aid_availability_details': None,
#    'has_lifebuoy': 'Yes',
#    'lifebuoy_details': None,
#    'has_lifeguard': 'No',
#    'lifeguard_availability': None,
#    'has_parking': 'Yes',
#    'parking_details': None,
#    'is_public_transport_available': 'No',
#    'public_transport_details': None,
#    'is_natural_sensitive_area': 'No',
#    'natural_sensitive_area_details': None,
#    'has_beach_activity_zones': 'No',
#    'beach_activity_zones_details': None,
#    'has_beach_information_board': 'No',
#    'beach_information_board_details': None,
#    'are_dogs_allowed_on_lead': 'No',
#    'dogs_allowed_on_lead_details': None,
#    'dogs_not_allowed': 'Yes',
#    'dogs_not_allowed_details': 'Dogs are not permitted during the bathing season (1st June-15th September)',
#    'cars_not_allowed_on_beach': 'Yes',
#    'cars_not_allowed_on_beach_details': None,
#    'cars_allowed_on_beach': 'No',
#    'cars_allowed_on_beach_details': None,
#    'has_car_free_zone': 'No',
#    'car_free_zone_details': None,
#    'has_litter_bin': 'Yes',
#    'litter_bin_details': None,
#    'has_recycling_facility': 'No',
#    'recycling_facility_details': None,
#    'last_updated': '2023-02-16T15:35:18'},
#   {'location_id': 13,
#    'beach_id': 'IESHBWC070_0000_0400',
#    'beach_name': 'Kilkee',
#    'hashtag': 'kilkee',
#    'county_name': 'Clare',
#    'local_authority_name': 'Clare County Council',
#    'easting': 88447,
#    'northing': 160053,
#    'beach_type': 'Identified Beach',
#    'beach_description': 'Kilkee is a crescent shaped beach of brown coloured, poorly sorted sand and it is fairly flat over most of its width. Due to the wave conditions on the beach, not many animals are to be found living in the sand. However there is a small variety of marine wildlife and the rocky shorelines on either side of Kilkee are rich hunting grounds for those interested in exploring rock-pools. Activities include swimming and sailing. Motorised watercraft, surfing and the use of canoes and kayaks is prohibited in close proximity to swimmers. Beach bye-laws are in place with horse riding and dogs prohibited between 11am and 6pm during the summer season.',
#    'annual_water_quality_assessment': 'Kilkee is classified as achieving Excellent Water Quality in 2021 based on the assessment of bacteriological results for the period 2018 to 2021. Kilkee has achieved an Excellent Water Quality rating for the four consecutive years 2018 to 2021. Annual water quality ratings are generally calculated using monitoring results over a four-year period and are assessed against stringent bacterial limits to protect bather health.',
#    'next_monitoring_date': None,
#    'beach_profile_url': 'https://www.beaches.ie/wp-content/files//profile/BWPR00622_2022_01_profile.pdf',
#    'profile_url_description': 'Profile for Kilkee for 2022',
#    'profile_last_updated_on': 2022,
#    'current_annual_water_quality_classification': None,
#    'current_annual_classification_year': None,
#    'year1_annual_water_quality_classification': 'Excellent Quality',
#    'year1_annual_classification_year': 2021,
#    'year2_annual_water_quality_classification': 'Excellent Quality',
#    'year2_annual_classification_year': 2020,
#    'year3_annual_water_quality_classification': 'Excellent Quality',
#    'year3_annual_classification_year': 2019,
#    'has_all_season_bathing_restriction_in_place': 'No',
#    'reason_for_all_season_bathing_restriction': None,
#    'short_term_pollution_risk': 'Yes',
#    'is_blue_flag': 'Yes',
#    'is_green_coast': 'No',
#    'has_toilets': 'Yes',
#    'toilet_details': None,
#    'is_disability_accessible': 'Yes',
#    'disability_accessible_details': 'Ramp leads onto beach',
#    'has_beach_wheelchair': 'Yes',
#    'beach_wheelchair_availability': 'Specially adapted beach Hippocampe chairs are available at Waterworld, Kilkee.The chairs, with specially-designed wheels, are free of charge and available seven days a week but must be booked in advance. Users will require a carer or personal assistance to operate them. Available through July and August 11am to 5:30pm. To make a booking please call Kilkee Waterworld 065-9056855',
#    'has_first_aid': 'Yes',
#    'first_aid_availability_details': 'Available at Lifeguard hut',
#    'has_lifebuoy': 'Yes',
#    'lifebuoy_details': None,
#    'has_lifeguard': 'Yes',
#    'lifeguard_availability': None,
#    'has_parking': 'Yes',
#    'parking_details': None,
#    'is_public_transport_available': 'Yes',
#    'public_transport_details': None,
#    'is_natural_sensitive_area': 'Yes',
#    'natural_sensitive_area_details': None,
#    'has_beach_activity_zones': 'No',
#    'beach_activity_zones_details': None,
#    'has_beach_information_board': 'Yes',
#    'beach_information_board_details': None,
#    'are_dogs_allowed_on_lead': 'Yes',
#    'dogs_allowed_on_lead_details': 'Before 11 am and after 6 pm during summer season, otherwise not allowed at all times onto beach during the summer.',
#    'dogs_not_allowed': 'No',
#    'dogs_not_allowed_details': None,
#    'cars_not_allowed_on_beach': 'Yes',
#    'cars_not_allowed_on_beach_details': None,
#    'cars_allowed_on_beach': 'No',
#    'cars_allowed_on_beach_details': None,
#    'has_car_free_zone': 'No',
#    'car_free_zone_details': None,
#    'has_litter_bin': 'Yes',
#    'litter_bin_details': None,
#    'has_recycling_facility': 'Yes',
#    'recycling_facility_details': None,
#    'last_updated': '2022-12-14T07:59:18'},
#   {'location_id': 14,
#    'beach_id': 'IESHBWL25_188_0100',
#    'beach_name': 'Lilliput, Lough Ennell',
#    'hashtag': 'lilliputl.ennell',
#    'county_name': 'Westmeath',
#    'local_authority_name': 'Westmeath County Council',
#    'easting': 237653,
#    'northing': 244415,
#    'beach_type': 'Identified Beach',
#    'beach_description': 'Lilliput is an inland water bathing area located on the shores of Lough Ennell. Lough Ennell supports a diverse aquatic flora. The bathing area is used by the adventure centre to teach children participating in summer camps about water safety and canoeing. The Mullingar Swimming Club hold an annual swim event at the bathing site. The bathing area extends over an area of approximately 55 meters wide and 1OO meters long (c.0.50Ha).',
# ...
#    'dogs_allowed_on_lead_details': None,
#    'dogs_not_allowed': 'No',
#    'dogs_not_allowed_details': None,
#    'cars_not_allowed_on_beach': 'No',
#    'cars_not_allowed_on_beach_details': None,
#    'cars_allowed_on_beach': 'No',
#    'cars_allowed_on_beach_details': None,
#    'has_car_free_zone': 'No',
#    'car_free_zone_details': None,
#    'has_litter_bin': 'No',
#    'litter_bin_details': None,
#    'has_recycling_facility': 'No',
#    'recycling_facility_details': None,
#    'last_updated': '2021-06-28T10:30:06'},
#   {'location_id': 1226,
#    'beach_id': 'BPNBF070000020002',
#    'beach_name': 'Merrion Strand',
#    'hashtag': 'merrionstrand',
#    'county_name': 'Dublin',
#    'local_authority_name': 'Dublin City Council',
#    'easting': 319763,
#    'northing': 231044,
#    'beach_type': 'Non-Identified Beach',
#    'beach_description': 'Merrion beach is a sandy beach with a gradual slope which makes the water too shallow for any real swimming. There is a large inlet of water that remains even at low tide and is known locally as "Cockle Lake". Although Merrion Strand itself has little flora or fauna due to its positioning and coastal connection to Sean Moore Park and the lrishtown nature Reserve, it is a nationally important area for migrating birds.Merrion Strand had been an identified/regulated bathing water and was monitored and managed under the terms of the 2008 Bathing Water Quality Regulations. Merrion Strand was declassified in 2020 due to Poor water quality - it had been classified as Poor for five consecutive years (2015 to 2019). Merrion Strand is no longer an identified/regulated bathing water, but continues to be monitored by Dublin City Council as an other monitored water.',
#    'annual_water_quality_assessment': None,
#    'next_monitoring_date': None,
#    'beach_profile_url': None,
#    'profile_url_description': None,
#    'profile_last_updated_on': None,
#    'current_annual_water_quality_classification': None,
#    'current_annual_classification_year': None,
#    'year1_annual_water_quality_classification': None,
#    'year1_annual_classification_year': None,
#    'year2_annual_water_quality_classification': None,
#    'year2_annual_classification_year': None,
#    'year3_annual_water_quality_classification': None,
#    'year3_annual_classification_year': None,
#    'has_all_season_bathing_restriction_in_place': None,
#    'reason_for_all_season_bathing_restriction': None,
#    'short_term_pollution_risk': None,
#    'is_blue_flag': 'No',
#    'is_green_coast': 'No',
#    'has_toilets': 'No',
#    'toilet_details': None,
#    'is_disability_accessible': 'No',
#    'disability_accessible_details': None,
#    'has_beach_wheelchair': 'No',
#    'beach_wheelchair_availability': None,
#    'has_first_aid': 'No',
#    'first_aid_availability_details': None,
#    'has_lifebuoy': 'No',
#    'lifebuoy_details': None,
#    'has_lifeguard': 'No',
#    'lifeguard_availability': None,
#    'has_parking': 'No',
#    'parking_details': None,
#    'is_public_transport_available': 'Yes',
#    'public_transport_details': 'The beach is served by both train and bus',
#    'is_natural_sensitive_area': 'Yes',
#    'natural_sensitive_area_details': None,
#    'has_beach_activity_zones': 'No',
#    'beach_activity_zones_details': None,
#    'has_beach_information_board': 'Yes',
#    'beach_information_board_details': None,
#    'are_dogs_allowed_on_lead': 'Yes',
#    'dogs_allowed_on_lead_details': 'Reference bye law for the control of dogs',
#    'dogs_not_allowed': 'No',
#    'dogs_not_allowed_details': None,
#    'cars_not_allowed_on_beach': 'No',
#    'cars_not_allowed_on_beach_details': None,
#    'cars_allowed_on_beach': 'No',
#    'cars_allowed_on_beach_details': None,
#    'has_car_free_zone': 'No',
#    'car_free_zone_details': None,
#    'has_litter_bin': 'No',
#    'litter_bin_details': None,
#    'has_recycling_facility': 'No',
#    'recycling_facility_details': None,
#    'last_updated': '2022-02-11T17:19:20'},
#   {'location_id': 1227,
#    'beach_id': 'BPNBF050000420001',
#    'beach_name': 'Ballynamona Strand',
#    'hashtag': 'ballynamonastrand',
#    'county_name': 'Cork',
#    'local_authority_name': 'Cork County Council',
#    'easting': 198650,
#    'northing': 65705,
#    'beach_type': 'Non-Identified Beach',
#    'beach_description': 'Ballynamona Beach is part of a line of beaches from Silver Strand on edge of Ballycotton village which connects to Ballynamona, which in turn connects to Ardnahinch Beach, which then connects to Garryvoe Beach, etc. It is sandy and sheltered and popular with walkers and surfers.',
#    'annual_water_quality_assessment': None,
#    'next_monitoring_date': None,
#    'beach_profile_url': None,
#    'profile_url_description': None,
#    'profile_last_updated_on': None,
#    'current_annual_water_quality_classification': None,
#    'current_annual_classification_year': None,
#    'year1_annual_water_quality_classification': None,
#    'year1_annual_classification_year': None,
#    'year2_annual_water_quality_classification': None,
#    'year2_annual_classification_year': None,
#    'year3_annual_water_quality_classification': None,
#    'year3_annual_classification_year': None,
#    'has_all_season_bathing_restriction_in_place': None,
#    'reason_for_all_season_bathing_restriction': None,
#    'short_term_pollution_risk': None,
#    'is_blue_flag': 'No',
#    'is_green_coast': 'Yes',
#    'has_toilets': 'No',
#    'toilet_details': None,
#    'is_disability_accessible': 'No',
#    'disability_accessible_details': None,
#    'has_beach_wheelchair': 'No',
#    'beach_wheelchair_availability': None,
#    'has_first_aid': 'No',
#    'first_aid_availability_details': None,
#    'has_lifebuoy': 'Yes',
#    'lifebuoy_details': None,
#    'has_lifeguard': 'No',
#    'lifeguard_availability': None,
#    'has_parking': 'Yes',
#    'parking_details': None,
#    'is_public_transport_available': 'No',
#    'public_transport_details': None,
#    'is_natural_sensitive_area': 'No',
#    'natural_sensitive_area_details': None,
#    'has_beach_activity_zones': 'No',
#    'beach_activity_zones_details': None,
#    'has_beach_information_board': 'Yes',
#    'beach_information_board_details': None,
#    'are_dogs_allowed_on_lead': 'Yes',
#    'dogs_allowed_on_lead_details': None,
#    'dogs_not_allowed': 'No',
#    'dogs_not_allowed_details': None,
#    'cars_not_allowed_on_beach': 'Yes',
#    'cars_not_allowed_on_beach_details': None,
#    'cars_allowed_on_beach': 'No',
#    'cars_allowed_on_beach_details': None,
#    'has_car_free_zone': 'No',
#    'car_free_zone_details': None,
#    'has_litter_bin': 'No',
#    'litter_bin_details': None,
#    'has_recycling_facility': 'No',
#    'recycling_facility_details': None,
#    'last_updated': '2022-02-10T13:19:09'},
#   {'location_id': 1228,
#    'beach_id': 'BPNPF050000410001',
#    'beach_name': 'Oileán Chléire',
#    'hashtag': 'oilenchlire',
#    'county_name': 'Cork',
#    'local_authority_name': 'Cork County Council',
#    'easting': 95724,
#    'northing': 21216,
#    'beach_type': 'Non-Identified Beach',
#    'beach_description': 'Oileán Chléire (Cape Clear Island) has an enviable location – right on the cusp of the continental shelf. The entrance to Roaringwater Bay is one of the leading dolphin, whale, leatherback turtles, sunfish, and shark sighting locations in Europe. The island has Ireland’s only manned bird observatory, which maintains a daily species log since 1959. Located two minutes’ walk from the ferry beach, the observatory is manned by a resident warden (March to November), and even offers birdwatchers hostel-style accommodation. There are various beaches and piers on Cape Clear suitable for swimming, one such area is Trá Coinlín (Coinlín Beach), South Harbour.',
#    'annual_water_quality_assessment': None,
#    'next_monitoring_date': None,
#    'beach_profile_url': None,
#    'profile_url_description': None,
#    'profile_last_updated_on': None,
#    'current_annual_water_quality_classification': None,
#    'current_annual_classification_year': None,
#    'year1_annual_water_quality_classification': None,
#    'year1_annual_classification_year': None,
#    'year2_annual_water_quality_classification': None,
#    'year2_annual_classification_year': None,
#    'year3_annual_water_quality_classification': None,
#    'year3_annual_classification_year': None,
#    'has_all_season_bathing_restriction_in_place': None,
#    'reason_for_all_season_bathing_restriction': None,
#    'short_term_pollution_risk': None,
#    'is_blue_flag': 'No',
#    'is_green_coast': 'No',
#    'has_toilets': 'No',
#    'toilet_details': None,
#    'is_disability_accessible': 'No',
#    'disability_accessible_details': None,
#    'has_beach_wheelchair': 'No',
#    'beach_wheelchair_availability': None,
#    'has_first_aid': 'No',
#    'first_aid_availability_details': None,
#    'has_lifebuoy': 'Yes',
#    'lifebuoy_details': None,
#    'has_lifeguard': 'No',
#    'lifeguard_availability': None,
#    'has_parking': 'No',
#    'parking_details': None,
#    'is_public_transport_available': 'No',
#    'public_transport_details': None,
#    'is_natural_sensitive_area': 'Yes',
#    'natural_sensitive_area_details': None,
#    'has_beach_activity_zones': 'No',
#    'beach_activity_zones_details': None,
#    'has_beach_information_board': 'Yes',
#    'beach_information_board_details': None,
#    'are_dogs_allowed_on_lead': 'Yes',
#    'dogs_allowed_on_lead_details': None,
#    'dogs_not_allowed': 'No',
#    'dogs_not_allowed_details': None,
#    'cars_not_allowed_on_beach': 'Yes',
#    'cars_not_allowed_on_beach_details': None,
#    'cars_allowed_on_beach': 'No',
#    'cars_allowed_on_beach_details': None,
#    'has_car_free_zone': 'No',
#    'car_free_zone_details': None,
#    'has_litter_bin': 'No',
#    'litter_bin_details': None,
#    'has_recycling_facility': 'No',
#    'recycling_facility_details': None,
#    'last_updated': '2022-02-10T13:18:45'},
#   {'location_id': 1229,
#    'beach_id': 'BPNBF120000060002',
#    'beach_name': 'Clifden Beach',
#    'hashtag': 'clifden',
#    'county_name': 'Galway',
#    'local_authority_name': 'Galway County Council',
#    'easting': 64130,
#    'northing': 250270,
#    'beach_type': 'Non-Identified Beach',
#    'beach_description': 'Clifden Beach is a small sheltered sandy beach located close to Clifden Town, 78kms to the west of Galway City on the shores of Clifden Bay. The bathing area is located down a narrow road called “The Beach Road” beside Clifden Boat Club and the RNLI Station. It is divided from a rocky shore and a mooring facility by a small grassy headland. There is a small seating area overlooking the rocky shore.Clifden Beach had been an identified/regulated bathing water and was monitored and managed under the terms of the 2008 Bathing Water Quality Regulations. Clifden Beach was declassified in 2021 due to Poor water quality - it had been classified as Poor for five consecutive years (2016 to 2020). Clifden Beach is no longer an identified/regulated bathing water, but continues to be monitored by Galway County Council as an other monitored water.',
#    'annual_water_quality_assessment': None,
#    'next_monitoring_date': None,
#    'beach_profile_url': None,
#    'profile_url_description': None,
#    'profile_last_updated_on': None,
#    'current_annual_water_quality_classification': None,
#    'current_annual_classification_year': None,
#    'year1_annual_water_quality_classification': None,
#    'year1_annual_classification_year': None,
#    'year2_annual_water_quality_classification': None,
#    'year2_annual_classification_year': None,
#    'year3_annual_water_quality_classification': None,
#    'year3_annual_classification_year': None,
#    'has_all_season_bathing_restriction_in_place': None,
#    'reason_for_all_season_bathing_restriction': None,
#    'short_term_pollution_risk': None,
#    'is_blue_flag': 'No',
#    'is_green_coast': 'No',
#    'has_toilets': 'Yes',
#    'toilet_details': None,
#    'is_disability_accessible': 'No',
#    'disability_accessible_details': None,
#    'has_beach_wheelchair': 'No',
#    'beach_wheelchair_availability': None,
#    'has_first_aid': 'No',
#    'first_aid_availability_details': None,
#    'has_lifebuoy': 'No',
#    'lifebuoy_details': None,
#    'has_lifeguard': 'No',
#    'lifeguard_availability': None,
#    'has_parking': 'Yes',
#    'parking_details': None,
#    'is_public_transport_available': 'No',
#    'public_transport_details': None,
#    'is_natural_sensitive_area': 'Yes',
#    'natural_sensitive_area_details': None,
#    'has_beach_activity_zones': 'No',
#    'beach_activity_zones_details': None,
#    'has_beach_information_board': 'Yes',
#    'beach_information_board_details': None,
#    'are_dogs_allowed_on_lead': 'Yes',
#    'dogs_allowed_on_lead_details': None,
#    'dogs_not_allowed': 'No',
#    'dogs_not_allowed_details': None,
#    'cars_not_allowed_on_beach': 'Yes',
#    'cars_not_allowed_on_beach_details': None,
#    'cars_allowed_on_beach': 'No',
#    'cars_allowed_on_beach_details': None,
#    'has_car_free_zone': 'No',
#    'car_free_zone_details': None,
#    'has_litter_bin': 'No',
#    'litter_bin_details': None,
#    'has_recycling_facility': 'No',
#    'recycling_facility_details': None,
#    'last_updated': '2022-03-01T11:02:09'},
#   {'location_id': 1230,
#    'beach_id': 'BPNBF050000410001',
#    'beach_name': 'Oileán Chléire',
#    'hashtag': 'oilenchlire',
#    'county_name': 'Cork',
#    'local_authority_name': 'Cork County Council',
#    'easting': 95724,
#    'northing': 21216,
#    'beach_type': 'Non-Identified Beach',
#    'beach_description': 'Oileán Chléire (Cape Clear Island) has an enviable location – right on the cusp of the continental shelf. The entrance to Roaringwater Bay is one of the leading dolphin, whale, leatherback turtles, sunfish, and shark sighting locations in Europe. The island has Ireland’s only manned bird observatory, which maintains a daily species log since 1959. Located two minutes’ walk from the ferry beach, the observatory is manned by a resident warden (March to November), and even offers birdwatchers hostel-style accommodation. There are various beaches and piers on Cape Clear suitable for swimming, one such area is Trá Coinlín (Coinlín Beach), South Harbour.',
#    'annual_water_quality_assessment': None,
#    'next_monitoring_date': None,
#    'beach_profile_url': None,
#    'profile_url_description': None,
#    'profile_last_updated_on': None,
#    'current_annual_water_quality_classification': None,
#    'current_annual_classification_year': None,
#    'year1_annual_water_quality_classification': None,
#    'year1_annual_classification_year': None,
#    'year2_annual_water_quality_classification': None,
#    'year2_annual_classification_year': None,
#    'year3_annual_water_quality_classification': None,
#    'year3_annual_classification_year': None,
#    'has_all_season_bathing_restriction_in_place': None,
#    'reason_for_all_season_bathing_restriction': None,
#    'short_term_pollution_risk': None,
#    'is_blue_flag': 'No',
#    'is_green_coast': 'No',
#    'has_toilets': 'No',
#    'toilet_details': None,
#    'is_disability_accessible': 'No',
#    'disability_accessible_details': None,
#    'has_beach_wheelchair': 'No',
#    'beach_wheelchair_availability': None,
#    'has_first_aid': 'No',
#    'first_aid_availability_details': None,
#    'has_lifebuoy': 'Yes',
#    'lifebuoy_details': None,
#    'has_lifeguard': 'No',
#    'lifeguard_availability': None,
#    'has_parking': 'No',
#    'parking_details': None,
#    'is_public_transport_available': 'No',
#    'public_transport_details': None,
#    'is_natural_sensitive_area': 'Yes',
#    'natural_sensitive_area_details': None,
#    'has_beach_activity_zones': 'No',
#    'beach_activity_zones_details': None,
#    'has_beach_information_board': 'Yes',
#    'beach_information_board_details': None,
#    'are_dogs_allowed_on_lead': 'Yes',
#    'dogs_allowed_on_lead_details': None,
#    'dogs_not_allowed': 'No',
#    'dogs_not_allowed_details': None,
#    'cars_not_allowed_on_beach': 'Yes',
#    'cars_not_allowed_on_beach_details': None,
#    'cars_allowed_on_beach': 'No',
#    'cars_allowed_on_beach_details': None,
#    'has_car_free_zone': 'No',
#    'car_free_zone_details': None,
#    'has_litter_bin': 'No',
#    'litter_bin_details': None,
#    'has_recycling_facility': 'No',
#    'recycling_facility_details': None,
#    'last_updated': '2022-03-07T12:49:14'}],
#  '_links': {'self': {'href': 'locations?page=1&per_page=500'}}}

# %%
dataSet = []
for item in data['list']:
    if item['current_annual_water_quality_classification']:
        currentClass =  item['current_annual_water_quality_classification']
    else:
        currentClass = item['year1_annual_water_quality_classification']

    # Easterling, Northerling


    dataSet.append([
        item['beach_id'],
        item['beach_name'],
        item['easting'],
        item['northing']
    ])

# %%
IrelandDF = pd.DataFrame(dataSet, columns=["id", "name", "northing", "easting"]).set_index('id')

# %%
geometry = [Point(x, y) for x, y in zip(IrelandDF['northing'], IrelandDF['easting'])]
for item in geometry:
    print(item.x, item.y)
# Out:
# 162397.0 215167.0
# 160627.0 43157.0
# 199890.0 67220.0
# 321720.0 160261.0
# 319664.0 141674.0
# 314791.0 287787.0
# 330865.0 182983.0
# 253215.0 268022.0
# 134654.0 180870.0
# 168753.0 176378.0
# 185949.0 203493.0
# 214971.0 296640.0
# 88447.0 160053.0
# 237653.0 244415.0
# 171256.0 186547.0
# 241921.0 258535.0
# 109500.0 222000.0
# 112610.0 221910.0
# 90566.0 283458.0
# 124690.0 209880.0
# 79753.0 281689.0
# 82978.0 210420.0
# 67320.0 298696.0
# 67359.0 308942.0
# 63715.0 325656.0
# 128040.0 329830.0
# 69296.0 309054.0
# 69630.0 238000.0
# 63761.0 304492.0
# 56089.0 304134.0
# 121932.0 332113.0
# 83456.0 282278.0
# 64411.0 323055.0
# 82729.0 295659.0
# 118250.0 222570.0
# 80067.0 340811.0
# 162660.0 340174.0
# 127151.0 223210.0
# 124854.0 222723.0
# 113500.0 222180.0
# 71405.0 285214.0
# 91259.0 223050.0
# 81211.0 229313.0
# 133970.0 213821.0
# 43471.0 65622.0
# 76578.0 25183.0
# 209750.0 75660.0
# 153930.0 43790.0
# 52411.0 58395.0
# 178620.0 58030.0
# 159935.0 43408.0
# 64269.0 100027.0
# 140190.0 38330.0
# 47900.0 67500.0
# 55613.0 88007.0
# 131217.0 34939.0
# 208931.0 74635.0
# 64443.0 91783.0
# 112150.0 28340.0
# 38220.0 100201.0
# 129788.0 35117.0
# 43527.0 79233.0
# 210550.0 76200.0
# 219200.0 78000.0
# 243400.0 98600.0
# 231500.0 93900.0
# 320142.0 156616.0
# 311568.0 127515.0
# 272939.0 108050.0
# 269100.0 100850.0
# 268900.0 100700.0
# 310265.0 114690.0
# 258600.0 101000.0
# 320340.0 264059.0
# 327295.0 218538.0
# 330650.0 182470.0
# 325233.0 169459.0
# 323291.0 236691.0
# 325151.0 249004.0
# 330000.0 211980.0
# 326088.0 224621.0
# 316460.0 273740.0
# 327263.0 256842.0
# 324873.0 244142.0
# 325664.0 251104.0
# 326414.0 253372.0
# 319550.0 232033.0
# 322823.0 228959.0
# 333663.0 190987.0
# 325700.0 260845.0
# 326648.0 239773.0
# 316409.0 283213.0
# 316021.0 279921.0
# 321594.0 305113.0
# 218930.0 444800.0
# 182007.0 359383.0
# 177786.0 421728.0
# 254278.0 450007.0
# 210126.0 438434.0
# 194472.0 435095.0
# 168546.0 376437.0
# 204684.0 437103.0
# 234270.0 431711.0
# 233152.0 427927.0
# 206473.0 436636.0
# 170950.0 356957.0
# 186120.0 367273.0
# 189312.0 372975.0
# 171092.0 399292.0
# 179962.0 428121.0
# 203076.0 437766.0
# 225049.0 438268.0
# 230071.0 427806.0
# 268283.0 442783.0
# 86033.0 141512.0
# 85819.0 141200.0
# 74815.0 127728.0
# 74791.0 122290.0
# 98517.0 154025.0
# 62706.0 114014.0
# 113693.0 208429.0
# 72627.0 115351.0
# 109291.0 187776.0
# 61899.0 115678.0
# 103362.0 177722.0
# 95455.0 167415.0
# 103824.0 180627.0
# 128908.0 223718.0
# 132104.0 224573.0
# 75066.0 277833.0
# 152670.0 335240.0
# 163710.0 350980.0
# 328014.0 239497.0
# 98210.0 202750.0
# 311843.0 128776.0
# 327200.0 254600.0
# 189110.0 433210.0
# 174910.0 402930.0
# 312952.0 106557.0
# 99325.0 173857.0
# 84717.0 30044.0
# 78870.0 24543.0
# 135751.0 33070.0
# 93503.0 31908.0
# 52195.0 42602.0
# 187686.0 60321.0
# 207854.0 71208.0
# 80052.0 36022.0
# 169732.0 50024.0
# 177201.0 53491.0
# 198827.0 66086.0
# 322363.0 233864.0
# 69423.0 238304.0
# 55740.0 264960.0
# 55203.0 265878.0
# 90400.0 224340.0
# 62928.0 245583.0
# 197815.0 216457.0
# 75731.0 264402.0
# 68690.0 263730.0
# 57563.0 256064.0
# 99002.0 201566.0
# 35431.0 105906.0
# 73053.0 111103.0
# 50157.0 66132.0
# 316028.0 275763.0
# 249906.0 98792.0
# 220605.0 80058.0
# 238224.0 97348.0
# 247394.0 98364.0
# 219955.0 79304.0
# 216459.0 77017.0
# 257218.0 99419.0
# 252665.0 98187.0
# 257125.0 99304.0
# 215776.0 77714.0
# 269596.0 104798.0
# 237005.0 96820.0
# 287497.0 107873.0
# 322001.0 145512.0
# 311452.0 126524.0
# 322285.0 146632.0
# 301066.0 104836.0
# 274893.0 105941.0
# 280134.0 105744.0
# 314618.0 110180.0
# 296685.0 103322.0
# 325626.0 172854.0
# 325821.0 228214.0
# 325774.0 228110.0
# 326379.0 225608.0
# 101120.0 25527.0
# 322276.0 235062.0
# 321135.0 233579.0
# 331293.0 207955.0
# 327051.0 219008.0
# 331813.0 194141.0
# 331199.0 195212.0
# 92873.0 148127.0
# 140482.0 38548.0
# 44393.0 81536.0
# 84471.0 152117.0
# 101936.0 175160.0
# 94660.0 223262.0
# 69717.0 97428.0
# 46269.0 68018.0
# 280133.0 103300.0
# 325208.0 171567.0
# 329684.0 212634.0
# 57188.0 243213.0
# 273627.0 146111.0
# 270705.0 162319.0
# 84055.0 344027.0
# 72262.0 326559.0
# 63222.0 320256.0
# 61920.0 274730.0
# 64050.0 330725.0
# 319763.0 231044.0
# 198650.0 65705.0
# 95724.0 21216.0
# 64130.0 250270.0
# 95724.0 21216.0

# %%
gdf = GeoDataFrame(IrelandDF, geometry=geometry).set_crs(29903)   
gdf
# Out:
#                                           name  northing  easting  \
# id
# IEWEBWL29_194_0100               Loughrea Lake    162397   215167
# IESWBWC090_0000_0300  Garrylucas, White Strand    160627    43157
# IESWBWC040_0000_0100                  Garryvoe    199890    67220
# IESEBWC010_0000_0500   Ballymoney, North Beach    321720   160261
# IESEBWC010_0000_0300              Morriscastle    319664   141674
# ...                                        ...       ...      ...
# BPNBF070000020002               Merrion Strand    319763   231044
# BPNBF050000420001           Ballynamona Strand    198650    65705
# BPNPF050000410001               Oileán Chléire     95724    21216
# BPNBF120000060002                Clifden Beach     64130   250270
# BPNBF050000410001               Oileán Chléire     95724    21216
#
#                                            geometry
# id
# IEWEBWL29_194_0100    POINT (162397.000 215167.000)
# IESWBWC090_0000_0300   POINT (160627.000 43157.000)
# IESWBWC040_0000_0100   POINT (199890.000 67220.000)
# IESEBWC010_0000_0500  POINT (321720.000 160261.000)
# IESEBWC010_0000_0300  POINT (319664.000 141674.000)
# ...                                             ...
# BPNBF070000020002     POINT (319763.000 231044.000)
# BPNBF050000420001      POINT (198650.000 65705.000)
# BPNPF050000410001       POINT (95724.000 21216.000)
# BPNBF120000060002      POINT (64130.000 250270.000)
# BPNBF050000410001       POINT (95724.000 21216.000)
#
# [222 rows x 4 columns]

# %%
gdf.crs
# Out:
# <Derived Projected CRS: EPSG:29903>
# Name: TM75 / Irish Grid
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Ireland - onshore. United Kingdom (UK) - Northern Ireland (Ulster) - onshore.
# - bounds: (-10.56, 51.39, -5.34, 55.43)
# Coordinate Operation:
# - name: Irish Grid
# - method: Transverse Mercator
# Datum: Geodetic Datum of 1965
# - Ellipsoid: Airy Modified 1849
# - Prime Meridian: Greenwich

# %%
gdf = gdf.to_crs(4326)

# %%
lat, long = [item.y for item in gdf['geometry']], [item.x for item in gdf['geometry']]

# %%
gdf['lat'] = lat
gdf['long'] = long

# %%
gdf = gdf.drop(columns=['easting', 'northing'])

# %%
gdf
# Out:
#                                           name                    geometry  \
# id
# IEWEBWL29_194_0100               Loughrea Lake   POINT (-8.56323 53.18591)
# IESWBWC090_0000_0300  Garrylucas, White Strand   POINT (-8.56946 51.64011)
# IESWBWC040_0000_0100                  Garryvoe   POINT (-8.00232 51.85775)
# IESEBWC010_0000_0500   Ballymoney, North Beach   POINT (-6.20098 52.68022)
# IESEBWC010_0000_0300              Morriscastle   POINT (-6.23808 52.51373)
# ...                                        ...                         ...
# BPNBF070000020002               Merrion Strand   POINT (-6.20370 53.31636)
# BPNBF050000420001           Ballynamona Strand   POINT (-8.02031 51.84413)
# BPNPF050000410001               Oileán Chléire   POINT (-9.50022 51.43469)
# BPNBF120000060002                Clifden Beach  POINT (-10.04757 53.48510)
# BPNBF050000410001               Oileán Chléire   POINT (-9.50022 51.43469)
#
#                             lat       long
# id
# IEWEBWL29_194_0100    53.185908  -8.563229
# IESWBWC090_0000_0300  51.640106  -8.569455
# IESWBWC040_0000_0100  51.857749  -8.002322
# IESEBWC010_0000_0500  52.680215  -6.200983
# IESEBWC010_0000_0300  52.513727  -6.238081
# ...                         ...        ...
# BPNBF070000020002     53.316365  -6.203700
# BPNBF050000420001     51.844132  -8.020314
# BPNPF050000410001     51.434690  -9.500225
# BPNBF120000060002     53.485103 -10.047573
# BPNBF050000410001     51.434690  -9.500225
#
# [222 rows x 4 columns]

# %%
gdf.to_csv('ireland.csv')
